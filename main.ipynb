# %%
from abacofs import ABACOFeatureSelector

import time
import matplotlib.pyplot as plt
import sys
import os
sys.path.append(os.path.abspath('.'))

# %%
# ACO CALL
fs = ABACOFeatureSelector(dtype='csv', data_training_name='./rtfDataSet.csv',
                          numberAnts=20, iterations=30, n_features=15)
# Out:
#           0         1         2         3         4         5         6
# 0  0.294244  0.705043  0.183047  0.610883  0.287570  0.806475  0.179009  \
# 1  0.315761  0.143673  0.263651  0.559548  0.330241  0.630611  0.174344
# 2  0.586875  0.397716  0.413937  0.667351  0.285714  0.785136  0.078134
# 3  0.481442  0.255947  0.506500  0.377823  0.270872  0.506990  0.232653
# 4  0.603012  0.574691  0.433177  0.394251  0.319109  0.431199  0.274052
#
#           7         8         9  ...        61        62        63        64
# 0  0.499009  0.890763  0.184259  ...  0.378264  0.459459  0.300824  0.339323  \
# 1  0.522299  0.433735  0.462037  ...  0.606916  0.529530  0.333791  0.389081
# 2  0.570367  0.506827  0.612037  ...  0.448836  0.623624  0.515110  0.374568
# 3  0.484143  0.623293  0.378704  ...  0.576570  0.377377  0.220467  0.291638
# 4  0.471754  0.575100  0.686111  ...  0.486944  0.438438  0.695055  0.379406
#
#          65        66        67        68        69  label
# 0  0.180758  0.348815  0.324151  0.526825  0.128294    0.0
# 1  0.332945  0.448341  0.433056  0.543741  0.221914    0.0
# 2  0.360933  0.509005  0.315823  0.435476  0.147712    0.0
# 3  0.143440  0.403791  0.410634  0.517641  0.126907    0.0
# 4  0.456560  0.371564  0.553491  0.523925  0.415395    1.0
#
# [5 rows x 71 columns]

# %%
fs.acoFS()
# Out:
# Colony 0 :
# 	Ant 0 :
# 		Path: [54, 56, 42, 52, 29, 59, 9, 22, 38, 18, 60, 33, 63, 50, 36]
# 		Accuracy: 0.6802259887005649
# 	Ant 1 :
# 		Path: [46, 44, 11, 19, 52, 9, 2, 68, 47, 28, 41, 13, 27, 65, 42]
# 		Accuracy: 0.6566666666666666
# 	Ant 2 :
# 		Path: [22, 38, 44, 52, 67, 11, 20, 37, 18, 1, 42, 9, 23, 8, 50]
# 		Accuracy: 0.7003954802259887
# 	Ant 3 :
# 		Path: [50, 16, 63, 25, 2, 10, 40, 52, 46, 14, 45, 54, 12, 49, 18]
# 		Accuracy: 0.6937853107344634
# 	Ant 4 :
# 		Path: [37, 51, 9, 15, 59, 16, 38, 63, 49, 11, 25, 14, 44, 8, 43]
# 		Accuracy: 0.700677966101695
# 	Ant 5 :
# 		Path: [42, 12, 28, 58, 9, 38, 8, 37, 65, 48, 2, 41, 44, 67, 22]
# 		Accuracy: 0.693502824858757
# 	Ant 6 :
# 		Path: [53, 1, 56, 30, 23, 16, 57, 64, 59, 2, 67, 52, 42, 38, 41]
# 		Accuracy: 0.6866666666666666
# 	Ant 7 :
# 		Path: [16, 32, 59, 6, 7, 9, 52, 11, 0, 38, 53, 5, 60, 44, 19]
# 		Accuracy: 0.6969491525423728
# 	Ant 8 :
# 		Path: [40, 38, 15, 11, 14, 54, 30, 12, 42, 59, 57, 50, 9, 51, 10]
# 		Accuracy: 0.693728813559322
# 	Ant 9 :
# 		Path: [60, 16, 42, 10, 2, 67, 15, 12, 11, 54, 38, 37, 58, 44, 9]
# 		Accuracy: 0.6834463276836158
# 	Ant 10 :
# 		Path: [31, 18, 67, 14, 53, 9, 59, 65, 46, 49, 58, 50, 25, 2, 11]
# 		Accuracy: 0.6833898305084746
# 	Ant 11 :
# 		Path: [63, 28, 12, 42, 14, 37, 44, 9, 67, 52, 46, 53, 15, 57, 16]
# 		Accuracy: 0.7036158192090396
# 	Ant 12 :
# 		Path: [63, 57, 10, 12, 14, 48, 51, 11, 19, 44, 2, 59, 45, 16, 37]
# 		Accuracy: 0.6766101694915254
# 	Ant 13 :
# 		Path: [64, 38, 57, 10, 54, 63, 19, 49, 9, 28, 34, 11, 14, 48, 65]
# 		Accuracy: 0.6936158192090395
# 	Ant 14 :
# 		Path: [9, 65, 14, 27, 12, 43, 49, 44, 0, 15, 10, 68, 67, 34, 11]
# 		Accuracy: 0.7171751412429378
# 	Ant 15 :
# 		Path: [11, 53, 14, 50, 67, 9, 40, 29, 57, 18, 63, 12, 43, 58, 38]
# 		Accuracy: 0.6665536723163842
# 	Ant 16 :
# 		Path: [65, 16, 2, 59, 10, 67, 44, 56, 19, 52, 51, 9, 48, 37, 63]
# 		Accuracy: 0.6563276836158192
# 	Ant 17 :
# 		Path: [14, 38, 66, 57, 2, 33, 29, 65, 53, 20, 42, 67, 10, 52, 50]
# 		Accuracy: 0.7238418079096045
# 	Ant 18 :
# 		Path: [12, 27, 38, 51, 8, 53, 22, 50, 49, 15, 37, 67, 47, 52, 58]
# 		Accuracy: 0.6731073446327683
# 	Ant 19 :
# 		Path: [30, 51, 9, 38, 14, 57, 12, 2, 63, 56, 59, 67, 24, 0, 65]
# 		Accuracy: 0.6936723163841807
# Colony 1 :
# 	Ant 0 :
# 		Path: [50, 9, 25, 15, 56, 63, 7, 44, 52, 11, 8, 51, 58, 38, 48]
# 		Accuracy: 0.6700564971751413
# 	Ant 1 :
# 		Path: [8, 50, 14, 63, 59, 57, 43, 5, 38, 44, 65, 69, 18, 27, 33]
# 		Accuracy: 0.6736158192090395
# 	Ant 2 :
# 		Path: [64, 28, 51, 32, 52, 2, 18, 44, 14, 57, 16, 65, 20, 63, 53]
# 		Accuracy: 0.7003954802259886
# 	Ant 3 :
# 		Path: [68, 41, 44, 16, 48, 9, 46, 52, 34, 67, 59, 0, 18, 65, 37]
# 		Accuracy: 0.6631073446327684
# 	Ant 4 :
# 		Path: [37, 65, 30, 16, 7, 57, 58, 11, 23, 63, 54, 50, 49, 5, 19]
# 		Accuracy: 0.6766666666666666
# 	Ant 5 :
# 		Path: [53, 50, 19, 59, 38, 29, 33, 28, 57, 37, 52, 8, 40, 10, 65]
# 		Accuracy: 0.6935593220338983
# 	Ant 6 :
# 		Path: [10, 18, 44, 49, 63, 38, 11, 12, 5, 9, 31, 40, 60, 19, 59]
# 		Accuracy: 0.6970056497175141
# 	Ant 7 :
# 		Path: [11, 50, 67, 10, 9, 54, 18, 58, 59, 44, 14, 49, 15, 46, 22]
# 		Accuracy: 0.6868361581920904
# 	Ant 8 :
# 		Path: [25, 11, 18, 44, 6, 48, 49, 41, 67, 60, 59, 28, 15, 50, 10]
# 		Accuracy: 0.693728813559322
# 	Ant 9 :
# 		Path: [8, 67, 38, 14, 60, 10, 63, 21, 52, 23, 46, 36, 6, 57, 11]
# 		Accuracy: 0.7207909604519773
# 	Ant 10 :
# 		Path: [49, 14, 34, 67, 38, 20, 16, 33, 63, 60, 25, 5, 43, 9, 41]
# 		Accuracy: 0.663502824858757
# 	Ant 11 :
# 		Path: [18, 28, 59, 9, 10, 38, 21, 50, 65, 46, 14, 43, 12, 34, 67]
# 		Accuracy: 0.7106779661016949
# 	Ant 12 :
# 		Path: [10, 16, 43, 53, 38, 59, 21, 28, 45, 19, 36, 11, 60, 26, 67]
# 		Accuracy: 0.7006214689265537
# 	Ant 13 :
# 		Path: [52, 20, 51, 63, 53, 27, 50, 67, 12, 2, 49, 6, 21, 11, 37]
# 		Accuracy: 0.6734463276836158
# 	Ant 14 :
# 		Path: [58, 20, 9, 38, 65, 15, 63, 12, 11, 42, 25, 68, 49, 6, 19]
# 		Accuracy: 0.6832768361581921
# 	Ant 15 :
# 		Path: [27, 20, 33, 57, 38, 10, 2, 28, 44, 52, 9, 51, 19, 49, 14]
# 		Accuracy: 0.7241807909604521
# 	Ant 16 :
# 		Path: [60, 46, 29, 37, 50, 8, 51, 19, 59, 53, 63, 52, 2, 49, 33]
# 		Accuracy: 0.754406779661017
# 	Ant 17 :
# 		Path: [23, 46, 52, 25, 2, 10, 20, 9, 63, 57, 48, 21, 65, 59, 19]
# 		Accuracy: 0.7005084745762712
# 	Ant 18 :
# 		Path: [19, 57, 23, 36, 8, 54, 16, 14, 49, 46, 18, 20, 52, 60, 12]
# 		Accuracy: 0.6970056497175141
# 	Ant 19 :
# 		Path: [44, 67, 15, 57, 19, 53, 0, 52, 54, 28, 49, 2, 8, 60, 16]
# 		Accuracy: 0.69045197740113
# Colony 2 :
# 	Ant 0 :
# 		Path: [63, 53, 48, 11, 38, 59, 42, 43, 13, 57, 2, 18, 65, 49, 44]
# 		Accuracy: 0.7136158192090395
# 	Ant 1 :
# 		Path: [29, 50, 63, 52, 19, 56, 25, 14, 59, 30, 16, 37, 57, 13, 60]
# 		Accuracy: 0.7136158192090396
# 	Ant 2 :
# 		Path: [33, 25, 16, 12, 10, 34, 44, 42, 48, 19, 11, 36, 27, 67, 20]
# 		Accuracy: 0.6969491525423728
# 	Ant 3 :
# 		Path: [63, 29, 37, 30, 0, 52, 41, 8, 42, 59, 21, 36, 15, 58, 57]
# 		Accuracy: 0.6901129943502824
# 	Ant 4 :
# 		Path: [42, 13, 43, 10, 65, 69, 56, 18, 31, 68, 48, 19, 36, 57, 14]
# 		Accuracy: 0.6396610169491526
# 	Ant 5 :
# 		Path: [50, 49, 41, 18, 14, 63, 57, 23, 27, 51, 0, 25, 38, 21, 34]
# 		Accuracy: 0.7002824858757062
# 	Ant 6 :
# 		Path: [56, 12, 14, 57, 30, 2, 25, 31, 18, 38, 59, 29, 16, 37, 50]
# 		Accuracy: 0.7202824858757062
# 	Ant 7 :
# 		Path: [58, 9, 53, 19, 57, 38, 52, 6, 48, 42, 20, 12, 54, 10, 50]
# 		Accuracy: 0.7305084745762711
# 	Ant 8 :
# 		Path: [43, 67, 63, 59, 23, 16, 30, 19, 68, 34, 38, 51, 46, 40, 2]
# 		Accuracy: 0.6633898305084747
# 	Ant 9 :
# 		Path: [56, 45, 10, 44, 16, 14, 46, 3, 49, 52, 18, 9, 20, 38, 31]
# 		Accuracy: 0.6936723163841807
# 	Ant 10 :
# 		Path: [21, 57, 50, 51, 9, 63, 14, 15, 40, 25, 54, 33, 30, 53, 19]
# 		Accuracy: 0.6934463276836158
# 	Ant 11 :
# 		Path: [43, 49, 8, 59, 50, 44, 30, 14, 35, 11, 57, 10, 65, 40, 22]
# 		Accuracy: 0.703728813559322
# 	Ant 12 :
# 		Path: [56, 0, 59, 49, 27, 22, 43, 54, 58, 21, 10, 12, 50, 33, 13]
# 		Accuracy: 0.6866101694915254
# 	Ant 13 :
# 		Path: [46, 67, 50, 10, 65, 59, 49, 44, 68, 52, 56, 53, 38, 12, 9]
# 		Accuracy: 0.6733898305084746
# 	Ant 14 :
# 		Path: [10, 63, 14, 44, 65, 51, 19, 41, 58, 25, 40, 23, 52, 12, 46]
# 		Accuracy: 0.6731638418079097
# 	Ant 15 :
# 		Path: [14, 56, 12, 63, 57, 29, 6, 9, 50, 23, 11, 10, 48, 33, 44]
# 		Accuracy: 0.6934463276836158
# 	Ant 16 :
# 		Path: [10, 12, 8, 13, 49, 63, 2, 52, 44, 59, 34, 31, 18, 67, 43]
# 		Accuracy: 0.6735593220338983
# 	Ant 17 :
# 		Path: [44, 8, 9, 34, 38, 52, 63, 37, 19, 42, 12, 16, 69, 30, 15]
# 		Accuracy: 0.6770056497175141
# 	Ant 18 :
# 		Path: [41, 56, 11, 67, 18, 37, 50, 65, 51, 21, 49, 15, 54, 38, 10]
# 		Accuracy: 0.6464971751412429
# 	Ant 19 :
# 		Path: [33, 38, 51, 9, 58, 23, 14, 18, 57, 11, 50, 44, 10, 25, 48]
# 		Accuracy: 0.6937853107344634
# Colony 3 :
# 	Ant 0 :
# 		Path: [43, 14, 44, 15, 38, 59, 27, 9, 40, 65, 11, 6, 2, 63, 50]
# 		Accuracy: 0.7238983050847457
# 	Ant 1 :
# 		Path: [52, 68, 19, 25, 59, 38, 40, 42, 57, 65, 16, 53, 49, 13, 58]
# 		Accuracy: 0.690225988700565
# 	Ant 2 :
# 		Path: [59, 12, 15, 38, 63, 11, 67, 43, 50, 18, 49, 19, 16, 36, 10]
# 		Accuracy: 0.700677966101695
# 	Ant 3 :
# 		Path: [31, 53, 63, 27, 52, 14, 36, 43, 57, 9, 51, 59, 68, 49, 67]
# 		Accuracy: 0.6799435028248587
# 	Ant 4 :
# 		Path: [29, 42, 59, 44, 34, 14, 57, 52, 49, 36, 15, 9, 47, 12, 19]
# 		Accuracy: 0.7006214689265537
# 	Ant 5 :
# 		Path: [67, 59, 57, 58, 12, 34, 18, 37, 44, 16, 46, 14, 31, 65, 40]
# 		Accuracy: 0.7033898305084746
# 	Ant 6 :
# 		Path: [37, 38, 9, 63, 19, 57, 28, 10, 53, 16, 30, 33, 54, 56, 14]
# 		Accuracy: 0.7205084745762711
# 	Ant 7 :
# 		Path: [67, 18, 38, 22, 63, 51, 59, 31, 28, 57, 12, 65, 11, 58, 14]
# 		Accuracy: 0.6832768361581921
# 	Ant 8 :
# 		Path: [28, 63, 49, 18, 24, 11, 14, 42, 25, 43, 29, 53, 48, 40, 9]
# 		Accuracy: 0.6633898305084746
# 	Ant 9 :
# 		Path: [49, 12, 40, 57, 63, 15, 20, 53, 16, 60, 19, 44, 23, 9, 51]
# 		Accuracy: 0.7206779661016949
# 	Ant 10 :
# 		Path: [63, 59, 11, 31, 65, 27, 68, 52, 25, 50, 18, 16, 14, 43, 44]
# 		Accuracy: 0.6797175141242938
# 	Ant 11 :
# 		Path: [2, 64, 29, 43, 12, 59, 38, 30, 46, 36, 28, 15, 68, 52, 19]
# 		Accuracy: 0.7308474576271187
# 	Ant 12 :
# 		Path: [22, 38, 65, 11, 7, 43, 59, 68, 28, 57, 63, 29, 16, 53, 6]
# 		Accuracy: 0.6970056497175141
# 	Ant 13 :
# 		Path: [63, 9, 49, 33, 25, 52, 50, 10, 51, 11, 43, 28, 18, 14, 58]
# 		Accuracy: 0.6666101694915254
# 	Ant 14 :
# 		Path: [53, 63, 57, 10, 50, 59, 65, 8, 49, 38, 67, 28, 52, 18, 20]
# 		Accuracy: 0.6906214689265535
# 	Ant 15 :
# 		Path: [40, 12, 43, 30, 9, 53, 21, 37, 48, 59, 38, 18, 19, 51, 24]
# 		Accuracy: 0.6768361581920905
# 	Ant 16 :
# 		Path: [16, 11, 9, 52, 67, 12, 38, 8, 46, 37, 56, 18, 14, 53, 68]
# 		Accuracy: 0.6937853107344634
# 	Ant 17 :
# 		Path: [53, 59, 16, 40, 36, 51, 42, 63, 34, 52, 28, 50, 9, 48, 6]
# 		Accuracy: 0.6933898305084745
# 	Ant 18 :
# 		Path: [59, 46, 14, 54, 52, 33, 67, 9, 57, 31, 49, 64, 41, 11, 28]
# 		Accuracy: 0.7002824858757062
# 	Ant 19 :
# 		Path: [52, 54, 50, 8, 44, 42, 56, 45, 59, 10, 37, 34, 58, 48, 19]
# 		Accuracy: 0.7271751412429378
# Colony 4 :
# 	Ant 0 :
# 		Path: [63, 31, 9, 41, 58, 22, 65, 21, 6, 49, 59, 37, 48, 12, 38]
# 		Accuracy: 0.7105084745762712
# 	Ant 1 :
# 		Path: [2, 65, 15, 0, 8, 42, 12, 59, 22, 33, 49, 19, 36, 41, 56]
# 		Accuracy: 0.6933898305084746
# 	Ant 2 :
# 		Path: [33, 11, 20, 22, 12, 47, 38, 44, 60, 63, 4, 58, 50, 54, 18]
# 		Accuracy: 0.6901129943502824
# 	Ant 3 :
# 		Path: [43, 2, 57, 19, 63, 21, 20, 53, 11, 27, 10, 60, 68, 47, 38]
# 		Accuracy: 0.7475706214689266
# 	Ant 4 :
# 		Path: [52, 41, 63, 2, 38, 65, 31, 53, 40, 44, 9, 37, 48, 59, 14]
# 		Accuracy: 0.713728813559322
# 	Ant 5 :
# 		Path: [29, 22, 49, 9, 38, 40, 10, 42, 47, 51, 14, 67, 33, 44, 48]
# 		Accuracy: 0.7071751412429379
# 	Ant 6 :
# 		Path: [61, 16, 19, 0, 6, 36, 38, 42, 28, 12, 67, 57, 2, 18, 8]
# 		Accuracy: 0.6868361581920903
# 	Ant 7 :
# 		Path: [53, 42, 14, 8, 52, 25, 37, 56, 57, 38, 48, 59, 16, 2, 46]
# 		Accuracy: 0.7509039548022599
# 	Ant 8 :
# 		Path: [43, 8, 14, 54, 44, 38, 23, 21, 9, 2, 19, 15, 12, 51, 18]
# 		Accuracy: 0.7040677966101694
# 	Ant 9 :
# 		Path: [65, 43, 57, 34, 59, 10, 28, 50, 14, 67, 38, 33, 49, 37, 20]
# 		Accuracy: 0.7172881355932204
# 	Ant 10 :
# 		Path: [6, 52, 25, 9, 65, 44, 10, 16, 57, 48, 63, 67, 23, 42, 50]
# 		Accuracy: 0.6698870056497175
# 	Ant 11 :
# 		Path: [67, 10, 56, 41, 18, 38, 60, 34, 59, 14, 0, 22, 16, 2, 21]
# 		Accuracy: 0.7410169491525422
# 	Ant 12 :
# 		Path: [40, 5, 11, 33, 65, 51, 52, 38, 44, 46, 30, 14, 49, 67, 18]
# 		Accuracy: 0.6731638418079097
# 	Ant 13 :
# 		Path: [65, 15, 58, 60, 5, 49, 20, 67, 9, 6, 29, 12, 18, 50, 51]
# 		Accuracy: 0.70045197740113
# 	Ant 14 :
# 		Path: [43, 57, 67, 10, 59, 29, 36, 63, 37, 45, 49, 28, 14, 44, 19]
# 		Accuracy: 0.6972881355932203
# 	Ant 15 :
# 		Path: [15, 28, 53, 14, 63, 30, 18, 38, 44, 68, 20, 29, 46, 10, 59]
# 		Accuracy: 0.74090395480226
# 	Ant 16 :
# 		Path: [63, 59, 34, 14, 29, 21, 65, 40, 33, 49, 12, 31, 18, 28, 47]
# 		Accuracy: 0.6833333333333333
# 	Ant 17 :
# 		Path: [57, 48, 10, 16, 67, 12, 25, 47, 45, 38, 68, 44, 9, 65, 6]
# 		Accuracy: 0.6900564971751412
# 	Ant 18 :
# 		Path: [30, 67, 50, 43, 25, 59, 10, 2, 64, 48, 41, 49, 63, 47, 51]
# 		Accuracy: 0.7068926553672317
# 	Ant 19 :
# 		Path: [38, 24, 33, 46, 57, 27, 10, 37, 16, 0, 19, 41, 31, 58, 22]
# 		Accuracy: 0.7003389830508475
# Colony 5 :
# 	Ant 0 :
# 		Path: [43, 68, 23, 18, 59, 67, 56, 54, 63, 2, 44, 25, 9, 60, 12]
# 		Accuracy: 0.6599435028248587
# 	Ant 1 :
# 		Path: [44, 25, 59, 67, 58, 49, 42, 57, 27, 53, 65, 19, 50, 18, 31]
# 		Accuracy: 0.6496610169491526
# 	Ant 2 :
# 		Path: [29, 15, 51, 27, 10, 67, 48, 38, 14, 6, 57, 56, 9, 59, 65]
# 		Accuracy: 0.7135593220338983
# 	Ant 3 :
# 		Path: [65, 6, 63, 23, 31, 10, 41, 28, 57, 18, 9, 38, 15, 68, 59]
# 		Accuracy: 0.6498305084745762
# 	Ant 4 :
# 		Path: [20, 49, 51, 29, 63, 38, 58, 19, 46, 43, 59, 42, 28, 12, 9]
# 		Accuracy: 0.7541807909604519
# 	Ant 5 :
# 		Path: [38, 21, 2, 8, 67, 59, 41, 25, 19, 46, 63, 52, 20, 53, 34]
# 		Accuracy: 0.7105084745762712
# 	Ant 6 :
# 		Path: [25, 38, 9, 11, 29, 15, 44, 56, 57, 42, 18, 49, 50, 7, 34]
# 		Accuracy: 0.6971186440677967
# 	Ant 7 :
# 		Path: [63, 40, 15, 50, 57, 19, 68, 52, 25, 37, 22, 8, 30, 59, 18]
# 		Accuracy: 0.7034463276836159
# 	Ant 8 :
# 		Path: [44, 31, 52, 9, 65, 59, 14, 42, 38, 30, 6, 33, 63, 12, 64]
# 		Accuracy: 0.703728813559322
# 	Ant 9 :
# 		Path: [9, 51, 10, 34, 20, 14, 50, 37, 16, 59, 63, 12, 68, 21, 49]
# 		Accuracy: 0.7103389830508474
# 	Ant 10 :
# 		Path: [8, 21, 65, 6, 63, 42, 19, 30, 20, 9, 12, 40, 59, 49, 50]
# 		Accuracy: 0.6866666666666666
# 	Ant 11 :
# 		Path: [28, 29, 41, 30, 33, 6, 11, 38, 31, 10, 9, 14, 67, 42, 0]
# 		Accuracy: 0.6733898305084746
# 	Ant 12 :
# 		Path: [38, 12, 67, 18, 59, 40, 50, 65, 37, 51, 33, 48, 34, 6, 44]
# 		Accuracy: 0.7035593220338983
# 	Ant 13 :
# 		Path: [14, 63, 60, 6, 49, 31, 57, 33, 53, 38, 42, 68, 47, 44, 11]
# 		Accuracy: 0.7071751412429379
# 	Ant 14 :
# 		Path: [8, 25, 18, 42, 63, 67, 59, 50, 57, 37, 10, 46, 52, 41, 30]
# 		Accuracy: 0.7204519774011299
# 	Ant 15 :
# 		Path: [43, 11, 25, 36, 59, 60, 14, 52, 63, 37, 10, 68, 58, 50, 51]
# 		Accuracy: 0.7036158192090396
# 	Ant 16 :
# 		Path: [43, 32, 44, 57, 63, 22, 42, 8, 30, 58, 50, 14, 38, 49, 12]
# 		Accuracy: 0.6866666666666668
# 	Ant 17 :
# 		Path: [7, 69, 50, 57, 52, 21, 10, 49, 59, 63, 9, 18, 38, 68, 44]
# 		Accuracy: 0.6970621468926554
# 	Ant 18 :
# 		Path: [59, 2, 30, 20, 38, 6, 54, 52, 25, 15, 63, 28, 14, 12, 9]
# 		Accuracy: 0.7173446327683616
# 	Ant 19 :
# 		Path: [14, 21, 59, 16, 63, 25, 9, 42, 37, 53, 18, 10, 15, 67, 65]
# 		Accuracy: 0.6736158192090395
# Colony 6 :
# 	Ant 0 :
# 		Path: [57, 53, 18, 33, 40, 0, 9, 23, 24, 13, 51, 54, 19, 34, 37]
# 		Accuracy: 0.7102824858757062
# 	Ant 1 :
# 		Path: [30, 15, 8, 40, 51, 43, 57, 52, 38, 63, 28, 25, 54, 49, 65]
# 		Accuracy: 0.7307344632768362
# 	Ant 2 :
# 		Path: [0, 37, 26, 28, 11, 19, 18, 38, 57, 59, 49, 10, 16, 25, 52]
# 		Accuracy: 0.6907344632768362
# 	Ant 3 :
# 		Path: [52, 8, 14, 54, 29, 60, 12, 59, 10, 40, 2, 30, 42, 46, 58]
# 		Accuracy: 0.7070056497175141
# 	Ant 4 :
# 		Path: [22, 51, 56, 52, 14, 34, 49, 42, 21, 58, 63, 30, 44, 23, 67]
# 		Accuracy: 0.6971186440677967
# 	Ant 5 :
# 		Path: [51, 57, 7, 22, 5, 37, 9, 24, 48, 52, 20, 10, 44, 38, 63]
# 		Accuracy: 0.7103389830508474
# 	Ant 6 :
# 		Path: [19, 9, 43, 67, 33, 49, 38, 12, 51, 37, 6, 45, 57, 63, 54]
# 		Accuracy: 0.734180790960452
# 	Ant 7 :
# 		Path: [38, 5, 49, 33, 8, 28, 53, 11, 65, 48, 52, 9, 50, 30, 60]
# 		Accuracy: 0.6870056497175141
# 	Ant 8 :
# 		Path: [6, 59, 53, 16, 67, 49, 38, 25, 2, 48, 63, 57, 21, 31, 44]
# 		Accuracy: 0.7204519774011299
# 	Ant 9 :
# 		Path: [44, 63, 51, 43, 9, 22, 54, 12, 40, 28, 31, 27, 10, 68, 48]
# 		Accuracy: 0.6832768361581921
# 	Ant 10 :
# 		Path: [68, 9, 37, 2, 38, 23, 44, 14, 59, 50, 51, 58, 10, 7, 33]
# 		Accuracy: 0.7406779661016949
# 	Ant 11 :
# 		Path: [14, 48, 50, 59, 49, 25, 11, 6, 10, 19, 33, 4, 65, 46, 56]
# 		Accuracy: 0.703728813559322
# 	Ant 12 :
# 		Path: [8, 43, 27, 10, 36, 28, 53, 0, 14, 52, 64, 23, 63, 12, 57]
# 		Accuracy: 0.7105084745762712
# 	Ant 13 :
# 		Path: [23, 36, 53, 54, 9, 65, 46, 56, 64, 14, 12, 18, 28, 42, 33]
# 		Accuracy: 0.6666101694915254
# 	Ant 14 :
# 		Path: [40, 59, 53, 60, 9, 6, 52, 43, 20, 28, 31, 67, 38, 57, 16]
# 		Accuracy: 0.7103954802259886
# 	Ant 15 :
# 		Path: [30, 48, 20, 69, 15, 19, 29, 49, 67, 8, 57, 63, 51, 28, 38]
# 		Accuracy: 0.7106779661016949
# 	Ant 16 :
# 		Path: [47, 6, 19, 14, 38, 63, 69, 11, 51, 37, 31, 43, 66, 50, 52]
# 		Accuracy: 0.7205649717514124
# 	Ant 17 :
# 		Path: [46, 51, 59, 65, 50, 54, 57, 67, 14, 44, 15, 9, 53, 49, 33]
# 		Accuracy: 0.6868926553672317
# 	Ant 18 :
# 		Path: [30, 2, 59, 45, 28, 25, 8, 34, 53, 52, 19, 38, 21, 22, 50]
# 		Accuracy: 0.6971751412429379
# 	Ant 19 :
# 		Path: [29, 49, 67, 13, 9, 20, 2, 52, 63, 41, 58, 43, 50, 38, 22]
# 		Accuracy: 0.71045197740113
# Colony 7 :
# 	Ant 0 :
# 		Path: [14, 12, 38, 65, 20, 21, 37, 7, 42, 41, 57, 58, 50, 9, 60]
# 		Accuracy: 0.7609039548022599
# 	Ant 1 :
# 		Path: [33, 10, 5, 57, 44, 11, 43, 31, 30, 6, 67, 37, 28, 42, 49]
# 		Accuracy: 0.7071751412429379
# 	Ant 2 :
# 		Path: [23, 30, 32, 54, 56, 63, 9, 46, 14, 53, 42, 52, 37, 31, 25]
# 		Accuracy: 0.713728813559322
# 	Ant 3 :
# 		Path: [12, 30, 44, 10, 57, 15, 67, 28, 64, 14, 43, 18, 63, 37, 16]
# 		Accuracy: 0.6803954802259887
# 	Ant 4 :
# 		Path: [37, 0, 24, 65, 51, 9, 46, 67, 6, 54, 16, 47, 48, 52, 59]
# 		Accuracy: 0.6970621468926553
# 	Ant 5 :
# 		Path: [57, 33, 63, 50, 38, 11, 34, 25, 22, 65, 18, 42, 27, 37, 59]
# 		Accuracy: 0.743954802259887
# 	Ant 6 :
# 		Path: [37, 38, 10, 2, 22, 19, 68, 50, 60, 54, 43, 51, 65, 20, 41]
# 		Accuracy: 0.7137853107344633
# 	Ant 7 :
# 		Path: [37, 61, 44, 25, 58, 59, 7, 31, 63, 19, 53, 12, 33, 11, 14]
# 		Accuracy: 0.7103389830508474
# 	Ant 8 :
# 		Path: [48, 9, 54, 14, 38, 40, 12, 44, 52, 10, 51, 63, 49, 50, 30]
# 		Accuracy: 0.7036158192090395
# 	Ant 9 :
# 		Path: [59, 23, 25, 63, 38, 67, 44, 22, 58, 8, 31, 56, 65, 2, 60]
# 		Accuracy: 0.6970056497175141
# 	Ant 10 :
# 		Path: [10, 43, 59, 42, 31, 12, 25, 38, 29, 28, 37, 9, 67, 44, 30]
# 		Accuracy: 0.693728813559322
# 	Ant 11 :
# 		Path: [57, 44, 52, 12, 65, 42, 0, 49, 16, 63, 51, 37, 15, 67, 9]
# 		Accuracy: 0.7038418079096045
# 	Ant 12 :
# 		Path: [14, 9, 10, 65, 64, 11, 67, 27, 19, 59, 56, 44, 12, 57, 38]
# 		Accuracy: 0.686949152542373
# 	Ant 13 :
# 		Path: [44, 59, 51, 63, 10, 22, 43, 12, 38, 40, 37, 34, 52, 41, 15]
# 		Accuracy: 0.71045197740113
# 	Ant 14 :
# 		Path: [37, 10, 44, 14, 29, 42, 13, 59, 9, 63, 67, 50, 56, 38, 22]
# 		Accuracy: 0.7273446327683615
# 	Ant 15 :
# 		Path: [0, 48, 8, 51, 56, 68, 43, 63, 49, 57, 37, 10, 23, 6, 67]
# 		Accuracy: 0.7035593220338983
# 	Ant 16 :
# 		Path: [15, 38, 0, 6, 51, 52, 14, 11, 42, 43, 25, 16, 10, 50, 12]
# 		Accuracy: 0.6766666666666665
# 	Ant 17 :
# 		Path: [28, 40, 65, 25, 63, 10, 23, 37, 53, 14, 46, 54, 57, 16, 56]
# 		Accuracy: 0.7140112994350283
# 	Ant 18 :
# 		Path: [54, 59, 63, 43, 60, 16, 28, 30, 53, 22, 37, 9, 38, 50, 14]
# 		Accuracy: 0.7003389830508475
# 	Ant 19 :
# 		Path: [12, 14, 46, 48, 38, 54, 20, 59, 44, 50, 30, 68, 63, 15, 40]
# 		Accuracy: 0.7204519774011299
# Colony 8 :
# 	Ant 0 :
# 		Path: [10, 12, 63, 42, 37, 14, 44, 34, 18, 52, 38, 25, 7, 59, 30]
# 		Accuracy: 0.6970056497175141
# 	Ant 1 :
# 		Path: [12, 24, 65, 8, 42, 36, 38, 50, 67, 21, 40, 41, 44, 63, 30]
# 		Accuracy: 0.6562711864406781
# 	Ant 2 :
# 		Path: [36, 23, 6, 29, 57, 34, 59, 65, 37, 0, 50, 30, 15, 38, 69]
# 		Accuracy: 0.7203954802259888
# 	Ant 3 :
# 		Path: [58, 51, 25, 0, 2, 67, 44, 11, 43, 12, 53, 63, 48, 9, 14]
# 		Accuracy: 0.6835593220338982
# 	Ant 4 :
# 		Path: [29, 59, 51, 57, 10, 25, 50, 58, 20, 16, 68, 63, 6, 27, 37]
# 		Accuracy: 0.7034463276836158
# 	Ant 5 :
# 		Path: [16, 27, 47, 36, 33, 43, 63, 2, 25, 58, 12, 57, 48, 53, 44]
# 		Accuracy: 0.6796610169491526
# 	Ant 6 :
# 		Path: [18, 50, 46, 59, 8, 63, 5, 23, 10, 11, 65, 6, 57, 41, 9]
# 		Accuracy: 0.6802259887005649
# 	Ant 7 :
# 		Path: [9, 31, 29, 38, 43, 30, 36, 23, 49, 59, 34, 25, 19, 14, 52]
# 		Accuracy: 0.7038418079096045
# 	Ant 8 :
# 		Path: [33, 64, 59, 0, 49, 69, 9, 65, 43, 63, 19, 67, 16, 13, 51]
# 		Accuracy: 0.6769491525423728
# 	Ant 9 :
# 		Path: [58, 22, 21, 53, 25, 52, 41, 8, 15, 54, 9, 12, 13, 10, 14]
# 		Accuracy: 0.6801129943502825
# 	Ant 10 :
# 		Path: [67, 15, 11, 63, 49, 41, 19, 9, 14, 25, 57, 10, 68, 29, 59]
# 		Accuracy: 0.6835028248587571
# 	Ant 11 :
# 		Path: [27, 23, 14, 37, 11, 48, 56, 51, 63, 15, 12, 44, 7, 31, 36]
# 		Accuracy: 0.6532203389830509
# 	Ant 12 :
# 		Path: [13, 57, 2, 25, 7, 63, 48, 68, 54, 8, 11, 59, 65, 50, 43]
# 		Accuracy: 0.6966666666666667
# 	Ant 13 :
# 		Path: [51, 25, 28, 57, 59, 20, 23, 14, 18, 37, 19, 68, 53, 58, 30]
# 		Accuracy: 0.7003389830508474
# 	Ant 14 :
# 		Path: [21, 51, 2, 59, 31, 50, 63, 28, 10, 52, 20, 44, 11, 25, 67]
# 		Accuracy: 0.7074011299435029
# 	Ant 15 :
# 		Path: [34, 33, 65, 50, 18, 11, 25, 57, 15, 10, 38, 63, 37, 51, 14]
# 		Accuracy: 0.7241807909604521
# 	Ant 16 :
# 		Path: [33, 52, 8, 43, 36, 38, 29, 13, 37, 56, 50, 28, 14, 54, 51]
# 		Accuracy: 0.6801694915254237
# 	Ant 17 :
# 		Path: [47, 37, 21, 51, 13, 68, 63, 20, 12, 7, 33, 65, 53, 59, 18]
# 		Accuracy: 0.6802824858757062
# 	Ant 18 :
# 		Path: [29, 33, 9, 50, 38, 7, 44, 57, 11, 63, 43, 14, 58, 19, 22]
# 		Accuracy: 0.7069491525423729
# 	Ant 19 :
# 		Path: [2, 22, 65, 38, 46, 14, 5, 37, 7, 57, 10, 9, 60, 63, 29]
# 		Accuracy: 0.7308474576271186
# Colony 9 :
# 	Ant 0 :
# 		Path: [43, 50, 16, 48, 31, 60, 25, 44, 36, 52, 10, 63, 57, 54, 11]
# 		Accuracy: 0.7136723163841807
# 	Ant 1 :
# 		Path: [2, 7, 59, 16, 43, 26, 65, 37, 11, 63, 52, 60, 30, 36, 42]
# 		Accuracy: 0.7107909604519774
# 	Ant 2 :
# 		Path: [47, 31, 15, 43, 22, 5, 46, 9, 53, 14, 50, 18, 44, 23, 11]
# 		Accuracy: 0.6733898305084746
# 	Ant 3 :
# 		Path: [27, 57, 56, 49, 16, 44, 67, 65, 48, 37, 22, 12, 10, 14, 55]
# 		Accuracy: 0.7171186440677966
# 	Ant 4 :
# 		Path: [43, 30, 44, 8, 50, 42, 49, 9, 54, 18, 37, 12, 25, 52, 38]
# 		Accuracy: 0.7037853107344633
# 	Ant 5 :
# 		Path: [3, 11, 33, 65, 15, 38, 37, 51, 34, 14, 31, 57, 50, 8, 21]
# 		Accuracy: 0.6870056497175142
# 	Ant 6 :
# 		Path: [44, 20, 59, 10, 42, 37, 33, 57, 63, 53, 19, 6, 9, 5, 14]
# 		Accuracy: 0.7203954802259886
# 	Ant 7 :
# 		Path: [12, 43, 67, 37, 68, 9, 42, 57, 14, 52, 50, 16, 6, 38, 1]
# 		Accuracy: 0.7338983050847456
# 	Ant 8 :
# 		Path: [49, 59, 57, 19, 36, 25, 42, 22, 29, 51, 67, 30, 52, 43, 20]
# 		Accuracy: 0.7005649717514124
# 	Ant 9 :
# 		Path: [51, 37, 25, 57, 59, 42, 21, 63, 12, 38, 8, 5, 46, 23, 54]
# 		Accuracy: 0.7305649717514124
# 	Ant 10 :
# 		Path: [52, 30, 56, 42, 38, 16, 36, 29, 19, 63, 51, 8, 57, 46, 44]
# 		Accuracy: 0.6765536723163842
# 	Ant 11 :
# 		Path: [15, 59, 0, 19, 52, 6, 28, 10, 43, 53, 44, 23, 63, 65, 46]
# 		Accuracy: 0.7240677966101694
# 	Ant 12 :
# 		Path: [58, 59, 13, 34, 57, 11, 0, 51, 46, 56, 12, 27, 38, 44, 63]
# 		Accuracy: 0.690225988700565
# 	Ant 13 :
# 		Path: [51, 14, 23, 37, 52, 36, 27, 16, 57, 13, 10, 1, 54, 25, 59]
# 		Accuracy: 0.6837288135593221
# 	Ant 14 :
# 		Path: [23, 68, 41, 48, 51, 53, 12, 38, 40, 10, 9, 15, 8, 56, 19]
# 		Accuracy: 0.6599435028248587
# 	Ant 15 :
# 		Path: [18, 63, 14, 25, 49, 20, 10, 6, 46, 59, 9, 50, 7, 54, 57]
# 		Accuracy: 0.7038418079096045
# 	Ant 16 :
# 		Path: [44, 23, 63, 59, 33, 28, 21, 52, 10, 6, 38, 9, 43, 2, 64]
# 		Accuracy: 0.717231638418079
# 	Ant 17 :
# 		Path: [48, 49, 10, 63, 44, 68, 12, 33, 11, 67, 19, 31, 20, 18, 54]
# 		Accuracy: 0.6903954802259886
# 	Ant 18 :
# 		Path: [59, 63, 67, 9, 5, 58, 24, 15, 34, 10, 44, 53, 38, 43, 69]
# 		Accuracy: 0.7103389830508474
# 	Ant 19 :
# 		Path: [50, 11, 15, 19, 47, 6, 9, 38, 8, 56, 59, 23, 58, 2, 28]
# 		Accuracy: 0.7306779661016949
# Colony 10 :
# 	Ant 0 :
# 		Path: [63, 49, 44, 31, 56, 12, 5, 19, 38, 18, 30, 14, 8, 33, 54]
# 		Accuracy: 0.6494915254237288
# 	Ant 1 :
# 		Path: [41, 67, 63, 34, 19, 48, 8, 56, 59, 11, 2, 40, 37, 9, 50]
# 		Accuracy: 0.6598305084745764
# 	Ant 2 :
# 		Path: [33, 14, 63, 50, 49, 53, 67, 37, 10, 68, 38, 18, 9, 30, 56]
# 		Accuracy: 0.6732768361581922
# 	Ant 3 :
# 		Path: [67, 48, 8, 14, 51, 28, 65, 63, 9, 12, 18, 56, 59, 29, 57]
# 		Accuracy: 0.6565536723163842
# 	Ant 4 :
# 		Path: [37, 51, 67, 38, 14, 19, 9, 60, 27, 8, 33, 53, 43, 44, 58]
# 		Accuracy: 0.683502824858757
# 	Ant 5 :
# 		Path: [16, 52, 9, 51, 63, 59, 6, 33, 11, 67, 57, 44, 25, 14, 41]
# 		Accuracy: 0.7003389830508474
# 	Ant 6 :
# 		Path: [33, 11, 68, 51, 44, 67, 52, 2, 65, 42, 15, 59, 50, 9, 6]
# 		Accuracy: 0.6868361581920903
# 	Ant 7 :
# 		Path: [24, 51, 8, 56, 12, 57, 63, 18, 23, 40, 2, 50, 44, 14, 6]
# 		Accuracy: 0.696497175141243
# 	Ant 8 :
# 		Path: [44, 59, 30, 6, 40, 38, 49, 67, 42, 25, 19, 63, 14, 37, 53]
# 		Accuracy: 0.7711299435028248
# 	Ant 9 :
# 		Path: [53, 28, 44, 22, 52, 63, 30, 59, 49, 12, 25, 6, 2, 65, 10]
# 		Accuracy: 0.7205649717514124
# 	Ant 10 :
# 		Path: [5, 67, 60, 52, 8, 64, 11, 51, 25, 15, 59, 22, 9, 44, 43]
# 		Accuracy: 0.6903389830508475
# 	Ant 11 :
# 		Path: [50, 67, 63, 11, 52, 65, 28, 14, 33, 43, 20, 57, 9, 44, 37]
# 		Accuracy: 0.7105649717514124
# 	Ant 12 :
# 		Path: [36, 11, 57, 40, 6, 14, 44, 12, 56, 9, 54, 38, 42, 67, 41]
# 		Accuracy: 0.6900000000000001
# 	Ant 13 :
# 		Path: [52, 20, 44, 23, 15, 10, 30, 24, 19, 0, 38, 12, 65, 60, 2]
# 		Accuracy: 0.6631638418079097
# 	Ant 14 :
# 		Path: [44, 23, 50, 56, 57, 2, 59, 14, 12, 36, 28, 63, 37, 43, 38]
# 		Accuracy: 0.717231638418079
# 	Ant 15 :
# 		Path: [43, 38, 24, 10, 48, 58, 12, 57, 9, 34, 67, 52, 53, 50, 45]
# 		Accuracy: 0.7610169491525424
# 	Ant 16 :
# 		Path: [63, 8, 20, 50, 9, 12, 58, 42, 46, 14, 2, 6, 16, 43, 37]
# 		Accuracy: 0.7003954802259886
# 	Ant 17 :
# 		Path: [33, 18, 19, 63, 37, 52, 49, 50, 25, 9, 28, 53, 16, 48, 43]
# 		Accuracy: 0.6938418079096045
# 	Ant 18 :
# 		Path: [50, 59, 20, 57, 10, 2, 51, 64, 19, 65, 40, 5, 22, 52, 49]
# 		Accuracy: 0.7138418079096046
# 	Ant 19 :
# 		Path: [22, 46, 63, 37, 19, 58, 6, 16, 67, 38, 14, 68, 12, 52, 44]
# 		Accuracy: 0.6833898305084746
# Colony 11 :
# 	Ant 0 :
# 		Path: [24, 37, 67, 21, 46, 16, 49, 33, 44, 47, 10, 59, 63, 57, 50]
# 		Accuracy: 0.6768926553672316
# 	Ant 1 :
# 		Path: [59, 67, 38, 56, 25, 2, 50, 20, 49, 52, 0, 11, 57, 42, 10]
# 		Accuracy: 0.727231638418079
# 	Ant 2 :
# 		Path: [22, 49, 11, 46, 2, 59, 14, 56, 0, 38, 33, 65, 67, 53, 42]
# 		Accuracy: 0.7168926553672316
# 	Ant 3 :
# 		Path: [43, 7, 37, 25, 18, 38, 11, 48, 69, 30, 65, 28, 20, 63, 23]
# 		Accuracy: 0.7038983050847458
# 	Ant 4 :
# 		Path: [65, 38, 22, 12, 20, 10, 36, 49, 34, 21, 44, 31, 46, 8, 14]
# 		Accuracy: 0.70045197740113
# 	Ant 5 :
# 		Path: [59, 67, 19, 2, 44, 3, 30, 63, 31, 36, 28, 6, 0, 18, 24]
# 		Accuracy: 0.7106779661016949
# 	Ant 6 :
# 		Path: [60, 2, 44, 50, 59, 63, 28, 29, 37, 57, 49, 14, 43, 47, 65]
# 		Accuracy: 0.7342372881355932
# 	Ant 7 :
# 		Path: [56, 68, 38, 44, 8, 18, 14, 63, 43, 16, 34, 36, 67, 40, 65]
# 		Accuracy: 0.6632203389830508
# 	Ant 8 :
# 		Path: [43, 22, 53, 44, 67, 20, 2, 9, 19, 58, 29, 31, 37, 38, 51]
# 		Accuracy: 0.6768926553672315
# 	Ant 9 :
# 		Path: [57, 37, 19, 42, 53, 59, 25, 23, 8, 58, 10, 38, 9, 54, 51]
# 		Accuracy: 0.6701694915254237
# 	Ant 10 :
# 		Path: [9, 33, 25, 56, 67, 14, 63, 49, 23, 46, 37, 43, 30, 10, 52]
# 		Accuracy: 0.6938418079096045
# 	Ant 11 :
# 		Path: [30, 63, 53, 29, 33, 48, 21, 34, 12, 14, 20, 6, 2, 50, 51]
# 		Accuracy: 0.6799999999999999
# 	Ant 12 :
# 		Path: [65, 63, 38, 59, 0, 9, 31, 14, 12, 11, 8, 50, 15, 41, 42]
# 		Accuracy: 0.6766101694915254
# 	Ant 13 :
# 		Path: [23, 21, 63, 65, 27, 33, 59, 37, 28, 50, 38, 12, 49, 18, 20]
# 		Accuracy: 0.7509604519774011
# 	Ant 14 :
# 		Path: [27, 56, 14, 18, 21, 13, 63, 22, 19, 36, 52, 40, 15, 59, 57]
# 		Accuracy: 0.6902824858757063
# 	Ant 15 :
# 		Path: [9, 11, 56, 59, 53, 27, 65, 14, 63, 54, 50, 69, 38, 67, 30]
# 		Accuracy: 0.7136158192090395
# 	Ant 16 :
# 		Path: [43, 12, 2, 67, 37, 10, 60, 59, 57, 14, 11, 50, 46, 19, 38]
# 		Accuracy: 0.7409039548022599
# 	Ant 17 :
# 		Path: [60, 36, 30, 57, 59, 38, 68, 46, 10, 37, 11, 15, 41, 6, 43]
# 		Accuracy: 0.733954802259887
# 	Ant 18 :
# 		Path: [18, 11, 31, 65, 21, 43, 63, 22, 16, 15, 52, 30, 67, 6, 59]
# 		Accuracy: 0.6632768361581921
# 	Ant 19 :
# 		Path: [57, 52, 25, 9, 28, 14, 18, 42, 12, 43, 2, 48, 20, 22, 21]
# 		Accuracy: 0.70045197740113
# Colony 12 :
# 	Ant 0 :
# 		Path: [67, 65, 18, 6, 41, 11, 25, 57, 21, 52, 56, 63, 31, 22, 43]
# 		Accuracy: 0.7070056497175141
# 	Ant 1 :
# 		Path: [63, 20, 58, 30, 10, 38, 43, 42, 44, 16, 29, 14, 27, 50, 53]
# 		Accuracy: 0.6932768361581921
# 	Ant 2 :
# 		Path: [59, 65, 27, 44, 63, 9, 48, 46, 21, 34, 8, 29, 53, 52, 67]
# 		Accuracy: 0.6802259887005649
# 	Ant 3 :
# 		Path: [15, 14, 22, 57, 64, 67, 19, 51, 49, 50, 5, 37, 20, 52, 10]
# 		Accuracy: 0.6868926553672317
# 	Ant 4 :
# 		Path: [44, 10, 65, 19, 2, 18, 50, 29, 37, 57, 12, 15, 51, 9, 59]
# 		Accuracy: 0.6835593220338984
# 	Ant 5 :
# 		Path: [51, 57, 24, 67, 36, 11, 52, 33, 37, 38, 60, 9, 14, 56, 68]
# 		Accuracy: 0.7171751412429378
# 	Ant 6 :
# 		Path: [19, 8, 38, 46, 48, 59, 64, 52, 7, 44, 18, 50, 14, 49, 67]
# 		Accuracy: 0.7174011299435028
# 	Ant 7 :
# 		Path: [11, 59, 63, 34, 57, 16, 20, 10, 23, 67, 50, 51, 48, 53, 37]
# 		Accuracy: 0.6866666666666666
# 	Ant 8 :
# 		Path: [50, 67, 48, 43, 65, 14, 59, 37, 11, 8, 69, 28, 25, 34, 42]
# 		Accuracy: 0.6666101694915254
# 	Ant 9 :
# 		Path: [44, 67, 9, 14, 18, 12, 43, 28, 68, 40, 23, 37, 63, 57, 13]
# 		Accuracy: 0.6970621468926554
# 	Ant 10 :
# 		Path: [10, 14, 22, 25, 42, 0, 46, 19, 52, 12, 50, 57, 65, 47, 37]
# 		Accuracy: 0.6799435028248587
# 	Ant 11 :
# 		Path: [54, 65, 12, 46, 44, 51, 15, 9, 52, 34, 11, 48, 63, 4, 50]
# 		Accuracy: 0.6633333333333333
# 	Ant 12 :
# 		Path: [13, 21, 43, 50, 51, 38, 31, 14, 9, 46, 52, 44, 57, 49, 22]
# 		Accuracy: 0.6800564971751413
# 	Ant 13 :
# 		Path: [31, 52, 49, 59, 12, 58, 57, 38, 34, 41, 9, 22, 19, 13, 15]
# 		Accuracy: 0.723954802259887
# 	Ant 14 :
# 		Path: [53, 6, 9, 56, 12, 47, 59, 18, 67, 57, 2, 40, 37, 11, 30]
# 		Accuracy: 0.6735593220338982
# 	Ant 15 :
# 		Path: [51, 44, 56, 49, 9, 12, 6, 37, 19, 41, 38, 29, 67, 18, 52]
# 		Accuracy: 0.6633898305084746
# 	Ant 16 :
# 		Path: [6, 9, 12, 38, 25, 59, 52, 31, 51, 57, 67, 63, 11, 43, 58]
# 		Accuracy: 0.707005649717514
# 	Ant 17 :
# 		Path: [11, 5, 12, 37, 38, 22, 16, 8, 63, 14, 57, 59, 20, 10, 25]
# 		Accuracy: 0.7002824858757062
# 	Ant 18 :
# 		Path: [44, 8, 41, 0, 11, 50, 63, 48, 19, 27, 59, 29, 18, 10, 9]
# 		Accuracy: 0.6868926553672317
# 	Ant 19 :
# 		Path: [64, 67, 31, 18, 43, 53, 27, 57, 25, 54, 44, 14, 50, 23, 37]
# 		Accuracy: 0.6833898305084746
# Colony 13 :
# 	Ant 0 :
# 		Path: [12, 14, 46, 68, 44, 57, 15, 63, 18, 65, 49, 56, 67, 11, 38]
# 		Accuracy: 0.6800564971751413
# 	Ant 1 :
# 		Path: [36, 48, 43, 9, 19, 16, 44, 10, 59, 38, 58, 52, 30, 42, 2]
# 		Accuracy: 0.7103389830508474
# 	Ant 2 :
# 		Path: [19, 36, 50, 14, 40, 67, 2, 53, 58, 33, 25, 41, 6, 13, 57]
# 		Accuracy: 0.6901129943502825
# 	Ant 3 :
# 		Path: [16, 48, 34, 43, 37, 50, 46, 19, 28, 30, 40, 65, 52, 44, 32]
# 		Accuracy: 0.7276271186440678
# 	Ant 4 :
# 		Path: [49, 5, 14, 12, 50, 19, 21, 45, 38, 43, 65, 40, 52, 37, 68]
# 		Accuracy: 0.7001694915254237
# 	Ant 5 :
# 		Path: [58, 48, 29, 49, 14, 44, 63, 6, 57, 10, 23, 67, 12, 33, 37]
# 		Accuracy: 0.723728813559322
# 	Ant 6 :
# 		Path: [51, 19, 50, 63, 7, 53, 59, 47, 60, 11, 44, 10, 8, 30, 9]
# 		Accuracy: 0.6699435028248588
# 	Ant 7 :
# 		Path: [11, 45, 51, 67, 65, 56, 25, 30, 9, 54, 38, 12, 52, 31, 43]
# 		Accuracy: 0.6568926553672316
# 	Ant 8 :
# 		Path: [11, 28, 25, 49, 42, 50, 34, 14, 18, 37, 58, 30, 67, 59, 44]
# 		Accuracy: 0.6901694915254237
# 	Ant 9 :
# 		Path: [63, 38, 22, 14, 8, 51, 44, 19, 37, 25, 49, 56, 11, 57, 60]
# 		Accuracy: 0.690225988700565
# 	Ant 10 :
# 		Path: [9, 52, 30, 43, 50, 25, 10, 60, 63, 8, 18, 51, 47, 12, 53]
# 		Accuracy: 0.6867796610169491
# 	Ant 11 :
# 		Path: [8, 40, 14, 37, 19, 57, 67, 30, 38, 51, 63, 11, 43, 42, 60]
# 		Accuracy: 0.7141242937853107
# 	Ant 12 :
# 		Path: [60, 9, 47, 10, 65, 23, 38, 54, 44, 51, 63, 1, 43, 57, 59]
# 		Accuracy: 0.7037853107344633
# 	Ant 13 :
# 		Path: [38, 21, 11, 18, 63, 57, 43, 44, 37, 52, 51, 14, 34, 19, 33]
# 		Accuracy: 0.7106214689265536
# 	Ant 14 :
# 		Path: [12, 23, 7, 52, 60, 18, 63, 43, 38, 58, 9, 33, 6, 2, 59]
# 		Accuracy: 0.7440677966101695
# 	Ant 15 :
# 		Path: [68, 40, 25, 51, 57, 56, 30, 38, 6, 48, 67, 14, 52, 16, 31]
# 		Accuracy: 0.6936158192090396
# 	Ant 16 :
# 		Path: [29, 53, 19, 63, 22, 20, 37, 9, 49, 56, 27, 23, 18, 14, 68]
# 		Accuracy: 0.6734463276836158
# 	Ant 17 :
# 		Path: [52, 18, 38, 27, 30, 41, 2, 44, 33, 59, 67, 14, 29, 49, 34]
# 		Accuracy: 0.7405649717514124
# 	Ant 18 :
# 		Path: [40, 12, 51, 31, 11, 19, 59, 5, 18, 14, 30, 49, 52, 34, 57]
# 		Accuracy: 0.6666101694915254
# 	Ant 19 :
# 		Path: [8, 49, 37, 40, 53, 63, 2, 59, 20, 9, 12, 51, 18, 50, 28]
# 		Accuracy: 0.7071186440677966
# Colony 14 :
# 	Ant 0 :
# 		Path: [54, 37, 50, 57, 12, 5, 38, 10, 51, 22, 14, 20, 9, 15, 44]
# 		Accuracy: 0.7070621468926552
# 	Ant 1 :
# 		Path: [36, 59, 33, 12, 57, 10, 58, 11, 41, 9, 68, 38, 13, 49, 15]
# 		Accuracy: 0.6969491525423728
# 	Ant 2 :
# 		Path: [23, 53, 63, 19, 4, 14, 3, 46, 8, 49, 18, 43, 27, 38, 40]
# 		Accuracy: 0.7073446327683616
# 	Ant 3 :
# 		Path: [65, 10, 14, 18, 36, 30, 50, 12, 67, 34, 16, 2, 52, 56, 0]
# 		Accuracy: 0.6900000000000001
# 	Ant 4 :
# 		Path: [10, 11, 30, 63, 5, 14, 50, 19, 67, 15, 47, 9, 65, 4, 59]
# 		Accuracy: 0.6499435028248588
# 	Ant 5 :
# 		Path: [16, 12, 27, 67, 10, 31, 25, 57, 20, 52, 29, 65, 58, 63, 38]
# 		Accuracy: 0.7036723163841808
# 	Ant 6 :
# 		Path: [57, 44, 11, 18, 58, 50, 54, 67, 53, 38, 52, 63, 25, 46, 42]
# 		Accuracy: 0.6634463276836158
# 	Ant 7 :
# 		Path: [67, 54, 36, 53, 9, 22, 50, 25, 51, 11, 12, 14, 30, 3, 41]
# 		Accuracy: 0.6430508474576271
# 	Ant 8 :
# 		Path: [22, 67, 63, 50, 53, 68, 57, 10, 11, 14, 44, 20, 38, 30, 12]
# 		Accuracy: 0.6971751412429379
# 	Ant 9 :
# 		Path: [43, 38, 51, 20, 58, 18, 57, 9, 54, 53, 16, 67, 30, 34, 25]
# 		Accuracy: 0.6768926553672316
# 	Ant 10 :
# 		Path: [46, 63, 28, 9, 58, 16, 11, 37, 56, 10, 18, 33, 6, 60, 69]
# 		Accuracy: 0.6766101694915255
# 	Ant 11 :
# 		Path: [8, 59, 9, 57, 51, 28, 38, 2, 18, 52, 27, 67, 11, 56, 22]
# 		Accuracy: 0.7340677966101695
# 	Ant 12 :
# 		Path: [36, 42, 9, 38, 59, 52, 44, 43, 27, 65, 14, 15, 67, 25, 10]
# 		Accuracy: 0.6767796610169492
# 	Ant 13 :
# 		Path: [22, 31, 63, 53, 25, 41, 9, 14, 59, 30, 57, 43, 48, 23, 51]
# 		Accuracy: 0.6801129943502825
# 	Ant 14 :
# 		Path: [68, 50, 49, 51, 28, 12, 42, 57, 25, 20, 27, 11, 43, 40, 58]
# 		Accuracy: 0.7033333333333334
# 	Ant 15 :
# 		Path: [57, 63, 34, 30, 2, 56, 23, 18, 9, 51, 14, 59, 13, 44, 38]
# 		Accuracy: 0.7103954802259886
# 	Ant 16 :
# 		Path: [19, 40, 50, 42, 11, 10, 67, 29, 52, 38, 15, 18, 65, 9, 63]
# 		Accuracy: 0.6497175141242938
# 	Ant 17 :
# 		Path: [24, 22, 15, 69, 45, 23, 46, 6, 33, 19, 38, 12, 10, 54, 14]
# 		Accuracy: 0.6598870056497176
# 	Ant 18 :
# 		Path: [42, 11, 59, 53, 20, 63, 48, 33, 10, 44, 67, 43, 2, 27, 64]
# 		Accuracy: 0.7138983050847457
# 	Ant 19 :
# 		Path: [44, 11, 29, 14, 50, 33, 10, 0, 60, 52, 2, 9, 58, 16, 40]
# 		Accuracy: 0.6732768361581921
# Colony 15 :
# 	Ant 0 :
# 		Path: [6, 9, 19, 50, 34, 16, 54, 45, 2, 56, 57, 30, 38, 14, 58]
# 		Accuracy: 0.6865536723163842
# 	Ant 1 :
# 		Path: [12, 2, 14, 50, 36, 53, 63, 9, 3, 42, 57, 25, 44, 38, 68]
# 		Accuracy: 0.7070056497175141
# 	Ant 2 :
# 		Path: [36, 40, 51, 57, 29, 63, 59, 49, 43, 9, 11, 27, 7, 44, 12]
# 		Accuracy: 0.6599435028248587
# 	Ant 3 :
# 		Path: [57, 14, 28, 18, 59, 33, 65, 22, 8, 9, 48, 10, 12, 24, 67]
# 		Accuracy: 0.6968926553672316
# 	Ant 4 :
# 		Path: [8, 23, 18, 2, 57, 68, 14, 11, 56, 63, 50, 9, 59, 34, 38]
# 		Accuracy: 0.6967231638418079
# 	Ant 5 :
# 		Path: [21, 12, 44, 38, 53, 6, 43, 50, 9, 36, 59, 58, 49, 37, 40]
# 		Accuracy: 0.7170056497175141
# 	Ant 6 :
# 		Path: [6, 57, 67, 18, 51, 63, 30, 50, 10, 38, 21, 65, 54, 59, 0]
# 		Accuracy: 0.6836158192090396
# 	Ant 7 :
# 		Path: [57, 9, 5, 30, 14, 19, 20, 56, 63, 68, 11, 49, 10, 22, 53]
# 		Accuracy: 0.6900564971751412
# 	Ant 8 :
# 		Path: [43, 52, 9, 49, 53, 68, 11, 7, 2, 63, 59, 6, 18, 42, 38]
# 		Accuracy: 0.7374011299435028
# 	Ant 9 :
# 		Path: [38, 54, 65, 18, 56, 52, 29, 2, 14, 23, 57, 59, 11, 63, 10]
# 		Accuracy: 0.7172881355932204
# 	Ant 10 :
# 		Path: [59, 10, 53, 16, 11, 58, 20, 52, 18, 44, 38, 34, 57, 54, 2]
# 		Accuracy: 0.6599435028248587
# 	Ant 11 :
# 		Path: [27, 42, 25, 43, 63, 2, 11, 20, 46, 67, 48, 19, 8, 38, 15]
# 		Accuracy: 0.7442372881355932
# 	Ant 12 :
# 		Path: [19, 42, 25, 18, 13, 6, 59, 9, 44, 28, 33, 48, 43, 30, 2]
# 		Accuracy: 0.7070621468926552
# 	Ant 13 :
# 		Path: [49, 63, 50, 11, 37, 16, 54, 51, 30, 68, 48, 57, 52, 12, 18]
# 		Accuracy: 0.6866666666666666
# 	Ant 14 :
# 		Path: [63, 23, 9, 16, 11, 22, 29, 69, 50, 68, 48, 58, 15, 10, 57]
# 		Accuracy: 0.6665536723163841
# 	Ant 15 :
# 		Path: [36, 10, 6, 51, 67, 47, 9, 44, 65, 24, 38, 56, 16, 14, 43]
# 		Accuracy: 0.6800564971751413
# 	Ant 16 :
# 		Path: [28, 43, 27, 51, 45, 59, 50, 37, 63, 65, 25, 15, 11, 67, 49]
# 		Accuracy: 0.7611864406779661
# 	Ant 17 :
# 		Path: [38, 37, 59, 65, 56, 14, 51, 22, 8, 28, 50, 34, 57, 19, 43]
# 		Accuracy: 0.7103954802259886
# 	Ant 18 :
# 		Path: [57, 59, 46, 41, 31, 37, 43, 22, 63, 51, 18, 0, 44, 14, 67]
# 		Accuracy: 0.6899435028248588
# 	Ant 19 :
# 		Path: [42, 44, 5, 33, 43, 22, 60, 12, 59, 29, 45, 38, 32, 10, 9]
# 		Accuracy: 0.7072881355932203
# Colony 16 :
# 	Ant 0 :
# 		Path: [57, 9, 20, 37, 42, 38, 67, 44, 45, 52, 25, 53, 47, 63, 40]
# 		Accuracy: 0.7273446327683615
# 	Ant 1 :
# 		Path: [18, 59, 50, 33, 43, 37, 52, 56, 19, 64, 51, 21, 34, 2, 38]
# 		Accuracy: 0.69045197740113
# 	Ant 2 :
# 		Path: [14, 48, 44, 27, 64, 25, 45, 63, 43, 38, 36, 28, 65, 60, 50]
# 		Accuracy: 0.693728813559322
# 	Ant 3 :
# 		Path: [30, 11, 63, 8, 38, 28, 59, 60, 19, 14, 53, 43, 48, 20, 51]
# 		Accuracy: 0.7070056497175141
# 	Ant 4 :
# 		Path: [67, 64, 52, 63, 33, 36, 27, 69, 9, 16, 37, 65, 50, 25, 51]
# 		Accuracy: 0.6664971751412428
# 	Ant 5 :
# 		Path: [63, 65, 25, 38, 10, 37, 18, 51, 50, 16, 60, 14, 34, 56, 9]
# 		Accuracy: 0.6937853107344634
# 	Ant 6 :
# 		Path: [50, 38, 33, 12, 68, 14, 44, 53, 21, 37, 18, 59, 51, 57, 27]
# 		Accuracy: 0.7206214689265538
# 	Ant 7 :
# 		Path: [34, 12, 59, 11, 57, 10, 36, 63, 51, 42, 19, 43, 15, 44, 65]
# 		Accuracy: 0.6564406779661016
# 	Ant 8 :
# 		Path: [49, 43, 8, 18, 11, 31, 44, 53, 16, 63, 59, 42, 67, 57, 15]
# 		Accuracy: 0.6936723163841808
# 	Ant 9 :
# 		Path: [28, 65, 1, 22, 51, 37, 48, 67, 18, 52, 46, 19, 30, 25, 14]
# 		Accuracy: 0.6870621468926553
# 	Ant 10 :
# 		Path: [18, 11, 59, 52, 53, 16, 37, 9, 49, 19, 6, 33, 14, 10, 30]
# 		Accuracy: 0.6903954802259886
# 	Ant 11 :
# 		Path: [28, 58, 63, 9, 37, 30, 18, 56, 22, 27, 40, 20, 45, 21, 11]
# 		Accuracy: 0.6973446327683614
# 	Ant 12 :
# 		Path: [14, 50, 10, 12, 38, 19, 44, 8, 63, 65, 40, 27, 21, 9, 51]
# 		Accuracy: 0.6735028248587571
# 	Ant 13 :
# 		Path: [49, 66, 50, 12, 43, 57, 9, 20, 48, 46, 29, 25, 4, 38, 30]
# 		Accuracy: 0.7406214689265536
# 	Ant 14 :
# 		Path: [48, 59, 51, 19, 21, 44, 43, 29, 63, 38, 40, 52, 14, 20, 50]
# 		Accuracy: 0.7172881355932204
# 	Ant 15 :
# 		Path: [34, 46, 48, 37, 44, 27, 15, 9, 56, 12, 49, 59, 67, 63, 57]
# 		Accuracy: 0.6902259887005651
# 	Ant 16 :
# 		Path: [42, 59, 48, 33, 22, 11, 10, 51, 46, 53, 19, 67, 49, 4, 50]
# 		Accuracy: 0.703502824858757
# 	Ant 17 :
# 		Path: [15, 24, 9, 51, 7, 48, 49, 63, 38, 40, 43, 6, 34, 53, 60]
# 		Accuracy: 0.727457627118644
# 	Ant 18 :
# 		Path: [14, 9, 12, 15, 59, 49, 67, 52, 29, 44, 50, 38, 5, 60, 33]
# 		Accuracy: 0.7070056497175141
# 	Ant 19 :
# 		Path: [63, 51, 65, 15, 36, 25, 44, 50, 68, 22, 59, 53, 16, 11, 37]
# 		Accuracy: 0.6666101694915254
# Colony 17 :
# 	Ant 0 :
# 		Path: [63, 9, 40, 53, 49, 46, 54, 11, 50, 22, 10, 34, 44, 52, 59]
# 		Accuracy: 0.7003389830508475
# 	Ant 1 :
# 		Path: [63, 6, 42, 5, 11, 14, 50, 65, 31, 9, 43, 38, 25, 37, 52]
# 		Accuracy: 0.7071186440677966
# 	Ant 2 :
# 		Path: [12, 38, 14, 57, 58, 44, 53, 19, 33, 9, 40, 48, 43, 63, 28]
# 		Accuracy: 0.713728813559322
# 	Ant 3 :
# 		Path: [10, 63, 23, 38, 37, 50, 60, 67, 43, 5, 16, 42, 22, 56, 41]
# 		Accuracy: 0.7037853107344633
# 	Ant 4 :
# 		Path: [9, 12, 51, 15, 57, 19, 13, 65, 18, 63, 34, 56, 50, 23, 11]
# 		Accuracy: 0.6566101694915254
# 	Ant 5 :
# 		Path: [33, 2, 57, 49, 65, 34, 37, 30, 29, 59, 19, 50, 44, 25, 23]
# 		Accuracy: 0.7610169491525424
# 	Ant 6 :
# 		Path: [63, 30, 10, 60, 52, 40, 69, 56, 11, 49, 43, 44, 53, 38, 37]
# 		Accuracy: 0.6635593220338982
# 	Ant 7 :
# 		Path: [14, 30, 18, 65, 61, 11, 10, 38, 68, 49, 46, 59, 43, 37, 22]
# 		Accuracy: 0.7207909604519773
# 	Ant 8 :
# 		Path: [38, 68, 10, 25, 7, 67, 9, 30, 50, 22, 31, 51, 59, 49, 42]
# 		Accuracy: 0.7203389830508475
# 	Ant 9 :
# 		Path: [40, 59, 57, 42, 44, 23, 34, 16, 28, 11, 14, 52, 18, 37, 9]
# 		Accuracy: 0.6903954802259886
# 	Ant 10 :
# 		Path: [63, 14, 41, 59, 57, 45, 49, 67, 27, 38, 25, 64, 53, 19, 21]
# 		Accuracy: 0.6733898305084747
# 	Ant 11 :
# 		Path: [10, 21, 15, 50, 37, 48, 43, 44, 57, 6, 22, 33, 14, 31, 29]
# 		Accuracy: 0.7203389830508475
# 	Ant 12 :
# 		Path: [2, 63, 36, 50, 47, 12, 42, 18, 0, 22, 52, 51, 38, 44, 53]
# 		Accuracy: 0.7070621468926553
# 	Ant 13 :
# 		Path: [67, 9, 63, 33, 27, 38, 34, 58, 42, 2, 10, 6, 52, 57, 18]
# 		Accuracy: 0.6870056497175142
# 	Ant 14 :
# 		Path: [63, 11, 43, 22, 28, 6, 0, 57, 67, 25, 8, 51, 46, 16, 38]
# 		Accuracy: 0.7069491525423728
# 	Ant 15 :
# 		Path: [28, 19, 22, 42, 52, 10, 69, 11, 50, 51, 43, 14, 45, 16, 36]
# 		Accuracy: 0.6598305084745762
# 	Ant 16 :
# 		Path: [57, 11, 14, 16, 52, 8, 9, 44, 20, 49, 67, 37, 31, 38, 60]
# 		Accuracy: 0.7036158192090395
# 	Ant 17 :
# 		Path: [30, 63, 53, 52, 65, 49, 23, 43, 2, 29, 0, 14, 54, 50, 48]
# 		Accuracy: 0.70045197740113
# 	Ant 18 :
# 		Path: [49, 59, 57, 53, 8, 10, 44, 11, 19, 65, 68, 52, 16, 48, 45]
# 		Accuracy: 0.6633898305084747
# 	Ant 19 :
# 		Path: [67, 43, 46, 57, 14, 44, 56, 12, 63, 38, 18, 59, 65, 50, 15]
# 		Accuracy: 0.6966666666666667
# Colony 18 :
# 	Ant 0 :
# 		Path: [9, 6, 65, 46, 51, 50, 33, 48, 57, 38, 10, 12, 20, 2, 13]
# 		Accuracy: 0.7170621468926553
# 	Ant 1 :
# 		Path: [51, 22, 10, 28, 53, 57, 42, 59, 27, 9, 49, 63, 65, 25, 29]
# 		Accuracy: 0.7001129943502825
# 	Ant 2 :
# 		Path: [6, 54, 63, 12, 43, 38, 28, 48, 18, 50, 46, 51, 59, 44, 19]
# 		Accuracy: 0.6868926553672317
# 	Ant 3 :
# 		Path: [11, 67, 65, 37, 33, 38, 15, 14, 23, 19, 40, 63, 9, 44, 41]
# 		Accuracy: 0.6667231638418079
# 	Ant 4 :
# 		Path: [52, 12, 20, 11, 65, 53, 38, 22, 34, 47, 9, 54, 27, 56, 46]
# 		Accuracy: 0.6631073446327684
# 	Ant 5 :
# 		Path: [33, 67, 18, 49, 63, 52, 19, 10, 14, 37, 0, 6, 38, 15, 54]
# 		Accuracy: 0.6903389830508475
# 	Ant 6 :
# 		Path: [9, 18, 49, 57, 59, 43, 5, 14, 16, 52, 37, 25, 28, 19, 33]
# 		Accuracy: 0.6938983050847458
# 	Ant 7 :
# 		Path: [21, 15, 22, 12, 9, 44, 63, 58, 19, 59, 16, 41, 38, 65, 57]
# 		Accuracy: 0.656497175141243
# 	Ant 8 :
# 		Path: [42, 49, 30, 57, 59, 11, 18, 38, 14, 3, 51, 15, 44, 33, 37]
# 		Accuracy: 0.700225988700565
# 	Ant 9 :
# 		Path: [10, 33, 8, 18, 30, 60, 46, 9, 16, 23, 12, 37, 44, 68, 14]
# 		Accuracy: 0.744406779661017
# 	Ant 10 :
# 		Path: [68, 21, 14, 50, 59, 67, 30, 33, 6, 42, 12, 8, 38, 25, 65]
# 		Accuracy: 0.6998870056497175
# 	Ant 11 :
# 		Path: [45, 19, 38, 51, 58, 25, 53, 52, 31, 28, 20, 63, 30, 44, 9]
# 		Accuracy: 0.7003954802259886
# 	Ant 12 :
# 		Path: [8, 63, 67, 50, 69, 60, 14, 12, 57, 30, 9, 52, 49, 59, 22]
# 		Accuracy: 0.7101129943502824
# 	Ant 13 :
# 		Path: [49, 31, 14, 65, 11, 38, 59, 19, 16, 12, 20, 46, 18, 50, 9]
# 		Accuracy: 0.6868361581920904
# 	Ant 14 :
# 		Path: [10, 38, 68, 65, 31, 40, 9, 42, 29, 37, 59, 16, 58, 50, 25]
# 		Accuracy: 0.7072316384180791
# 	Ant 15 :
# 		Path: [37, 10, 48, 14, 19, 11, 6, 15, 21, 12, 67, 57, 50, 16, 68]
# 		Accuracy: 0.6563276836158192
# 	Ant 16 :
# 		Path: [27, 63, 69, 14, 67, 57, 43, 0, 11, 41, 19, 33, 53, 18, 65]
# 		Accuracy: 0.6331638418079096
# 	Ant 17 :
# 		Path: [49, 50, 67, 28, 59, 63, 52, 19, 0, 23, 18, 68, 9, 8, 48]
# 		Accuracy: 0.7001129943502825
# 	Ant 18 :
# 		Path: [40, 29, 12, 0, 50, 52, 2, 14, 9, 56, 63, 43, 51, 42, 38]
# 		Accuracy: 0.6936158192090395
# 	Ant 19 :
# 		Path: [29, 40, 18, 14, 44, 20, 16, 41, 63, 10, 50, 57, 9, 25, 30]
# 		Accuracy: 0.7003954802259886
# Colony 19 :
# 	Ant 0 :
# 		Path: [21, 36, 42, 10, 49, 59, 65, 37, 44, 7, 28, 18, 25, 19, 6]
# 		Accuracy: 0.7106214689265536
# 	Ant 1 :
# 		Path: [60, 68, 43, 14, 50, 47, 28, 46, 12, 42, 30, 7, 65, 52, 15]
# 		Accuracy: 0.6497175141242938
# 	Ant 2 :
# 		Path: [13, 43, 59, 28, 12, 48, 36, 30, 22, 24, 25, 38, 51, 19, 16]
# 		Accuracy: 0.683502824858757
# 	Ant 3 :
# 		Path: [28, 67, 50, 63, 46, 49, 44, 22, 2, 40, 9, 38, 16, 43, 15]
# 		Accuracy: 0.7103389830508474
# 	Ant 4 :
# 		Path: [42, 48, 2, 63, 51, 60, 50, 41, 3, 12, 19, 29, 38, 44, 43]
# 		Accuracy: 0.7000564971751413
# 	Ant 5 :
# 		Path: [23, 37, 2, 59, 50, 67, 57, 12, 38, 10, 16, 65, 11, 0, 49]
# 		Accuracy: 0.7071751412429379
# 	Ant 6 :
# 		Path: [13, 63, 42, 29, 30, 10, 16, 59, 51, 27, 38, 60, 8, 24, 18]
# 		Accuracy: 0.693728813559322
# 	Ant 7 :
# 		Path: [12, 49, 2, 29, 28, 50, 60, 18, 57, 7, 44, 51, 8, 33, 59]
# 		Accuracy: 0.7170621468926555
# 	Ant 8 :
# 		Path: [27, 46, 18, 43, 52, 53, 38, 30, 13, 67, 57, 10, 19, 12, 31]
# 		Accuracy: 0.6902824858757063
# 	Ant 9 :
# 		Path: [53, 0, 37, 38, 49, 20, 16, 12, 63, 6, 54, 52, 19, 10, 25]
# 		Accuracy: 0.70045197740113
# 	Ant 10 :
# 		Path: [15, 13, 14, 65, 51, 50, 48, 57, 10, 38, 63, 44, 45, 58, 22]
# 		Accuracy: 0.7003389830508475
# 	Ant 11 :
# 		Path: [42, 50, 9, 59, 67, 34, 18, 44, 4, 46, 14, 10, 12, 22, 51]
# 		Accuracy: 0.7070621468926552
# 	Ant 12 :
# 		Path: [42, 48, 60, 44, 18, 13, 59, 52, 16, 38, 56, 25, 14, 19, 6]
# 		Accuracy: 0.6936158192090395
# 	Ant 13 :
# 		Path: [54, 9, 50, 27, 48, 58, 43, 67, 46, 16, 11, 65, 57, 53, 19]
# 		Accuracy: 0.6631073446327684
# 	Ant 14 :
# 		Path: [37, 46, 57, 63, 15, 25, 5, 49, 0, 8, 50, 67, 44, 6, 59]
# 		Accuracy: 0.7407909604519773
# 	Ant 15 :
# 		Path: [49, 52, 22, 42, 51, 6, 21, 9, 15, 38, 10, 7, 50, 43, 29]
# 		Accuracy: 0.713954802259887
# 	Ant 16 :
# 		Path: [59, 16, 21, 57, 42, 63, 51, 44, 11, 53, 41, 14, 25, 49, 56]
# 		Accuracy: 0.6867796610169492
# 	Ant 17 :
# 		Path: [37, 28, 50, 43, 42, 7, 49, 38, 9, 44, 6, 11, 59, 67, 57]
# 		Accuracy: 0.7442937853107344
# 	Ant 18 :
# 		Path: [60, 3, 12, 43, 38, 51, 44, 59, 50, 58, 8, 52, 63, 37, 29]
# 		Accuracy: 0.7106779661016949
# 	Ant 19 :
# 		Path: [22, 12, 53, 33, 42, 19, 44, 20, 48, 51, 46, 63, 11, 9, 2]
# 		Accuracy: 0.690225988700565
# Colony 20 :
# 	Ant 0 :
# 		Path: [58, 0, 22, 38, 42, 20, 14, 36, 37, 6, 63, 12, 44, 57, 25]
# 		Accuracy: 0.743954802259887
# 	Ant 1 :
# 		Path: [59, 63, 34, 16, 49, 43, 47, 53, 20, 44, 33, 38, 54, 12, 42]
# 		Accuracy: 0.7103389830508474
# 	Ant 2 :
# 		Path: [30, 38, 60, 22, 48, 23, 29, 8, 15, 63, 52, 14, 54, 53, 47]
# 		Accuracy: 0.6867231638418078
# 	Ant 3 :
# 		Path: [49, 57, 44, 10, 56, 50, 53, 63, 65, 20, 36, 41, 28, 14, 31]
# 		Accuracy: 0.6866101694915254
# 	Ant 4 :
# 		Path: [49, 18, 58, 23, 51, 16, 37, 44, 68, 19, 33, 38, 67, 14, 43]
# 		Accuracy: 0.707005649717514
# 	Ant 5 :
# 		Path: [57, 65, 48, 58, 63, 22, 49, 30, 14, 9, 25, 10, 13, 47, 54]
# 		Accuracy: 0.7206214689265535
# 	Ant 6 :
# 		Path: [30, 9, 52, 59, 69, 46, 63, 0, 38, 44, 45, 12, 18, 50, 67]
# 		Accuracy: 0.6566101694915254
# 	Ant 7 :
# 		Path: [14, 11, 65, 63, 67, 29, 37, 57, 19, 59, 50, 12, 53, 46, 27]
# 		Accuracy: 0.703728813559322
# 	Ant 8 :
# 		Path: [40, 53, 57, 67, 32, 63, 10, 24, 68, 36, 22, 50, 43, 11, 38]
# 		Accuracy: 0.6901694915254237
# 	Ant 9 :
# 		Path: [37, 69, 34, 33, 50, 20, 23, 25, 42, 58, 63, 18, 13, 30, 28]
# 		Accuracy: 0.6631638418079097
# 	Ant 10 :
# 		Path: [65, 59, 44, 20, 51, 52, 25, 11, 57, 19, 14, 48, 36, 22, 67]
# 		Accuracy: 0.700677966101695
# 	Ant 11 :
# 		Path: [52, 33, 53, 30, 43, 59, 14, 54, 38, 44, 41, 46, 9, 56, 67]
# 		Accuracy: 0.7170621468926553
# 	Ant 12 :
# 		Path: [6, 59, 10, 43, 60, 0, 51, 50, 15, 9, 19, 8, 37, 18, 28]
# 		Accuracy: 0.7172881355932204
# 	Ant 13 :
# 		Path: [67, 56, 6, 60, 48, 22, 44, 40, 63, 28, 38, 11, 57, 59, 50]
# 		Accuracy: 0.6431638418079096
# 	Ant 14 :
# 		Path: [10, 56, 63, 57, 67, 44, 43, 14, 8, 48, 38, 19, 64, 65, 33]
# 		Accuracy: 0.7306779661016949
# 	Ant 15 :
# 		Path: [50, 57, 9, 22, 65, 54, 52, 12, 8, 44, 38, 58, 46, 43, 18]
# 		Accuracy: 0.737231638418079
# 	Ant 16 :
# 		Path: [37, 8, 38, 65, 9, 63, 18, 11, 14, 33, 50, 7, 40, 0, 16]
# 		Accuracy: 0.7205649717514124
# 	Ant 17 :
# 		Path: [57, 45, 19, 43, 37, 60, 42, 22, 38, 11, 14, 59, 9, 51, 44]
# 		Accuracy: 0.713954802259887
# 	Ant 18 :
# 		Path: [59, 29, 14, 10, 50, 9, 43, 44, 67, 63, 11, 37, 38, 21, 24]
# 		Accuracy: 0.6903389830508475
# 	Ant 19 :
# 		Path: [59, 36, 10, 46, 16, 58, 9, 57, 14, 12, 37, 65, 8, 48, 51]
# 		Accuracy: 0.7138983050847457
# Colony 21 :
# 	Ant 0 :
# 		Path: [67, 19, 54, 44, 30, 65, 22, 43, 27, 0, 63, 14, 6, 37, 12]
# 		Accuracy: 0.6971186440677967
# 	Ant 1 :
# 		Path: [59, 61, 63, 56, 11, 25, 49, 20, 44, 8, 0, 14, 47, 10, 9]
# 		Accuracy: 0.6970056497175141
# 	Ant 2 :
# 		Path: [30, 44, 8, 52, 38, 34, 27, 65, 9, 46, 6, 19, 49, 51, 47]
# 		Accuracy: 0.6835593220338982
# 	Ant 3 :
# 		Path: [63, 65, 24, 8, 0, 16, 12, 68, 13, 57, 44, 27, 52, 51, 47]
# 		Accuracy: 0.6733333333333335
# 	Ant 4 :
# 		Path: [43, 19, 0, 65, 59, 37, 49, 63, 25, 12, 57, 42, 38, 2, 6]
# 		Accuracy: 0.7274576271186441
# 	Ant 5 :
# 		Path: [34, 2, 46, 8, 12, 38, 49, 44, 51, 36, 50, 14, 48, 25, 43]
# 		Accuracy: 0.7170056497175141
# 	Ant 6 :
# 		Path: [31, 49, 11, 46, 33, 38, 37, 18, 9, 53, 42, 59, 20, 63, 22]
# 		Accuracy: 0.7375141242937853
# 	Ant 7 :
# 		Path: [42, 19, 10, 13, 12, 27, 25, 44, 14, 11, 6, 9, 51, 67, 59]
# 		Accuracy: 0.6734463276836158
# 	Ant 8 :
# 		Path: [59, 11, 10, 56, 38, 53, 49, 0, 50, 14, 60, 65, 42, 5, 43]
# 		Accuracy: 0.6934463276836157
# 	Ant 9 :
# 		Path: [19, 59, 9, 38, 58, 31, 6, 11, 14, 24, 16, 18, 44, 42, 27]
# 		Accuracy: 0.7136158192090395
# 	Ant 10 :
# 		Path: [6, 5, 59, 57, 67, 63, 12, 14, 27, 17, 42, 18, 33, 9, 38]
# 		Accuracy: 0.6933333333333334
# 	Ant 11 :
# 		Path: [11, 23, 37, 64, 10, 21, 8, 49, 42, 16, 31, 56, 2, 14, 18]
# 		Accuracy: 0.7106214689265536
# 	Ant 12 :
# 		Path: [25, 63, 10, 57, 9, 5, 16, 58, 53, 59, 48, 49, 67, 52, 2]
# 		Accuracy: 0.723954802259887
# 	Ant 13 :
# 		Path: [67, 58, 63, 14, 65, 54, 30, 31, 38, 57, 11, 46, 51, 33, 53]
# 		Accuracy: 0.6734463276836158
# 	Ant 14 :
# 		Path: [30, 37, 33, 67, 52, 2, 7, 38, 42, 59, 18, 6, 12, 50, 10]
# 		Accuracy: 0.7070056497175141
# 	Ant 15 :
# 		Path: [7, 2, 51, 65, 37, 28, 21, 6, 49, 44, 27, 60, 5, 18, 59]
# 		Accuracy: 0.7172881355932204
# 	Ant 16 :
# 		Path: [15, 12, 23, 52, 14, 10, 19, 21, 63, 46, 50, 53, 11, 9, 58]
# 		Accuracy: 0.6732768361581921
# 	Ant 17 :
# 		Path: [63, 29, 37, 43, 42, 49, 10, 57, 52, 67, 23, 14, 48, 19, 38]
# 		Accuracy: 0.7509604519774011
# 	Ant 18 :
# 		Path: [23, 50, 63, 40, 46, 24, 14, 27, 8, 51, 19, 38, 53, 12, 21]
# 		Accuracy: 0.6802259887005648
# 	Ant 19 :
# 		Path: [28, 56, 53, 6, 50, 22, 25, 8, 63, 51, 20, 45, 49, 12, 52]
# 		Accuracy: 0.6937853107344633
# Colony 22 :
# 	Ant 0 :
# 		Path: [67, 19, 9, 14, 37, 49, 63, 43, 3, 48, 58, 51, 29, 41, 10]
# 		Accuracy: 0.6463276836158192
# 	Ant 1 :
# 		Path: [44, 57, 8, 63, 25, 50, 42, 2, 15, 18, 23, 10, 4, 37, 53]
# 		Accuracy: 0.6901694915254237
# 	Ant 2 :
# ...
# 		Accuracy: 0.7238418079096045
# 	Ant 13 :
# 		Path: [11, 14, 49, 24, 28, 30, 10, 68, 9, 57, 21, 0, 59, 67, 44]
# 		Accuracy: 0.7070056497175141
# 	Ant 14 :
# 		Path: [58, 63, 50, 36, 11, 12, 37, 64, 10, 54, 8, 57, 56, 14, 38]
# 		Accuracy: 0.6868926553672317
# 	Ant 15 :
# 		Path: [44, 57, 9, 67, 34, 59, 14, 49, 50, 63, 12, 11, 51, 37, 56]
# 		Accuracy: 0.6833898305084746
# 	Ant 16 :
# 		Path: [16, 37, 58, 20, 47, 44, 50, 49, 59, 9, 45, 52, 8, 25, 41]
# 		Accuracy: 0.7238418079096045
# 	Ant 17 :
# 		Path: [9, 63, 51, 18, 49, 38, 59, 54, 25, 42, 34, 50, 2, 47, 66]
# 		Accuracy: 0.7168926553672316
# 	Ant 18 :
# 		Path: [30, 33, 43, 58, 38, 11, 57, 63, 19, 54, 44, 15, 13, 16, 12]
# 		Accuracy: 0.7172881355932204
# 	Ant 19 :
# 		Path: [16, 44, 31, 18, 19, 15, 58, 21, 12, 60, 67, 50, 52, 30, 63]
# 		Accuracy: 0.6430508474576271
# Colony 23 :
# 	Ant 0 :
# 		Path: [11, 57, 1, 27, 68, 37, 59, 28, 44, 38, 52, 0, 20, 48, 9]
# 		Accuracy: 0.7103954802259886
# 	Ant 1 :
# 		Path: [59, 14, 31, 57, 24, 8, 3, 9, 51, 49, 12, 43, 10, 28, 37]
# 		Accuracy: 0.6970621468926554
# 	Ant 2 :
# 		Path: [59, 63, 67, 57, 50, 25, 44, 28, 54, 14, 52, 2, 68, 16, 36]
# 		Accuracy: 0.7107344632768362
# 	Ant 3 :
# 		Path: [25, 63, 11, 22, 42, 37, 28, 29, 52, 27, 67, 59, 18, 14, 8]
# 		Accuracy: 0.6933898305084746
# 	Ant 4 :
# 		Path: [65, 27, 33, 12, 22, 47, 44, 9, 59, 40, 56, 6, 25, 37, 50]
# 		Accuracy: 0.7033898305084746
# 	Ant 5 :
# 		Path: [24, 10, 22, 14, 43, 25, 57, 59, 51, 31, 42, 9, 30, 65, 19]
# 		Accuracy: 0.7338983050847457
# 	Ant 6 :
# 		Path: [68, 11, 63, 14, 38, 25, 37, 29, 59, 19, 48, 49, 32, 50, 43]
# 		Accuracy: 0.6937853107344633
# 	Ant 7 :
# 		Path: [29, 57, 53, 31, 18, 54, 37, 56, 44, 16, 51, 9, 19, 65, 7]
# 		Accuracy: 0.67
# 	Ant 8 :
# 		Path: [38, 56, 16, 7, 52, 67, 12, 44, 6, 14, 48, 10, 18, 59, 51]
# 		Accuracy: 0.6734463276836158
# 	Ant 9 :
# 		Path: [13, 14, 49, 63, 59, 15, 11, 23, 47, 33, 57, 44, 12, 42, 53]
# 		Accuracy: 0.6733333333333332
# 	Ant 10 :
# 		Path: [59, 19, 44, 67, 10, 52, 37, 11, 54, 43, 0, 56, 12, 15, 22]
# 		Accuracy: 0.6866101694915254
# 	Ant 11 :
# 		Path: [53, 40, 67, 52, 51, 57, 48, 15, 65, 59, 2, 14, 63, 50, 37]
# 		Accuracy: 0.6868361581920903
# 	Ant 12 :
# 		Path: [27, 57, 18, 30, 50, 19, 43, 10, 21, 25, 34, 59, 33, 37, 51]
# 		Accuracy: 0.7340677966101695
# 	Ant 13 :
# 		Path: [14, 11, 0, 51, 57, 33, 67, 31, 41, 59, 19, 9, 38, 22, 45]
# 		Accuracy: 0.6835028248587571
# 	Ant 14 :
# 		Path: [65, 50, 43, 7, 14, 19, 63, 49, 37, 51, 54, 2, 22, 18, 33]
# 		Accuracy: 0.7241242937853107
# 	Ant 15 :
# 		Path: [38, 43, 65, 49, 64, 52, 14, 37, 54, 8, 50, 59, 40, 51, 28]
# 		Accuracy: 0.7306214689265537
# 	Ant 16 :
# 		Path: [46, 8, 30, 9, 49, 63, 58, 10, 14, 54, 59, 37, 19, 61, 51]
# 		Accuracy: 0.727231638418079
# 	Ant 17 :
# 		Path: [57, 63, 65, 51, 42, 27, 50, 48, 16, 43, 18, 46, 56, 68, 26]
# 		Accuracy: 0.6830508474576271
# 	Ant 18 :
# 		Path: [22, 59, 15, 28, 38, 31, 52, 8, 51, 63, 9, 25, 42, 67, 19]
# 		Accuracy: 0.6802259887005648
# 	Ant 19 :
# 		Path: [69, 3, 30, 65, 23, 8, 34, 31, 18, 49, 38, 46, 56, 7, 50]
# 		Accuracy: 0.7136723163841807
# Colony 24 :
# 	Ant 0 :
# 		Path: [68, 19, 20, 53, 11, 54, 14, 36, 37, 49, 16, 38, 59, 25, 12]
# 		Accuracy: 0.71045197740113
# 	Ant 1 :
# 		Path: [28, 67, 25, 44, 19, 49, 11, 38, 59, 57, 10, 30, 22, 68, 15]
# 		Accuracy: 0.7074576271186441
# 	Ant 2 :
# 		Path: [63, 48, 43, 10, 50, 9, 18, 33, 19, 0, 32, 42, 46, 38, 30]
# 		Accuracy: 0.6938418079096046
# 	Ant 3 :
# 		Path: [52, 67, 28, 19, 13, 14, 27, 10, 11, 59, 65, 37, 43, 42, 40]
# 		Accuracy: 0.6634463276836158
# 	Ant 4 :
# 		Path: [67, 30, 69, 11, 14, 38, 8, 49, 60, 9, 28, 12, 50, 68, 65]
# 		Accuracy: 0.65
# 	Ant 5 :
# 		Path: [57, 11, 63, 16, 50, 8, 60, 10, 67, 9, 30, 65, 4, 40, 59]
# 		Accuracy: 0.6767796610169492
# 	Ant 6 :
# 		Path: [14, 42, 52, 63, 41, 25, 19, 56, 9, 31, 53, 6, 22, 2, 46]
# 		Accuracy: 0.6866666666666668
# 	Ant 7 :
# 		Path: [58, 63, 46, 19, 49, 30, 48, 44, 52, 16, 15, 56, 68, 59, 12]
# 		Accuracy: 0.6867231638418079
# 	Ant 8 :
# 		Path: [14, 65, 21, 50, 10, 57, 15, 22, 67, 44, 53, 18, 38, 49, 63]
# 		Accuracy: 0.6871186440677965
# 	Ant 9 :
# 		Path: [43, 38, 48, 25, 52, 59, 50, 0, 9, 2, 57, 42, 37, 28, 51]
# 		Accuracy: 0.7340677966101696
# 	Ant 10 :
# 		Path: [43, 38, 48, 52, 57, 31, 9, 14, 67, 16, 2, 63, 40, 68, 23]
# 		Accuracy: 0.6968361581920903
# 	Ant 11 :
# 		Path: [53, 57, 48, 44, 68, 11, 10, 9, 22, 59, 51, 12, 34, 67, 25]
# 		Accuracy: 0.6932768361581921
# 	Ant 12 :
# 		Path: [11, 20, 63, 38, 49, 12, 48, 14, 9, 16, 47, 18, 57, 58, 50]
# 		Accuracy: 0.7172881355932204
# 	Ant 13 :
# 		Path: [58, 25, 29, 54, 11, 63, 22, 12, 56, 9, 60, 50, 14, 43, 28]
# 		Accuracy: 0.669774011299435
# 	Ant 14 :
# 		Path: [51, 63, 37, 57, 59, 53, 43, 67, 4, 42, 9, 40, 12, 10, 33]
# 		Accuracy: 0.6733333333333333
# 	Ant 15 :
# 		Path: [28, 9, 44, 65, 59, 50, 43, 8, 25, 19, 5, 2, 42, 49, 15]
# 		Accuracy: 0.7271751412429378
# 	Ant 16 :
# 		Path: [44, 63, 59, 8, 67, 64, 43, 42, 50, 16, 19, 37, 11, 20, 29]
# 		Accuracy: 0.6766666666666666
# 	Ant 17 :
# 		Path: [12, 67, 36, 46, 16, 65, 68, 14, 50, 22, 51, 59, 63, 8, 57]
# 		Accuracy: 0.696497175141243
# 	Ant 18 :
# 		Path: [9, 30, 42, 57, 67, 38, 50, 48, 46, 33, 44, 52, 59, 12, 63]
# 		Accuracy: 0.7036723163841808
# 	Ant 19 :
# 		Path: [9, 12, 25, 23, 21, 22, 40, 6, 58, 56, 49, 11, 8, 43, 53]
# 		Accuracy: 0.7206214689265537
# Colony 25 :
# 	Ant 0 :
# 		Path: [9, 18, 14, 11, 2, 49, 41, 43, 38, 20, 59, 57, 23, 44, 52]
# 		Accuracy: 0.737231638418079
# 	Ant 1 :
# 		Path: [68, 14, 67, 19, 25, 52, 37, 27, 43, 59, 48, 56, 57, 63, 2]
# 		Accuracy: 0.7306214689265536
# 	Ant 2 :
# 		Path: [9, 49, 25, 30, 33, 16, 53, 38, 19, 12, 6, 43, 65, 22, 51]
# 		Accuracy: 0.6768926553672315
# 	Ant 3 :
# 		Path: [31, 21, 37, 19, 63, 22, 28, 11, 40, 65, 27, 60, 33, 20, 49]
# 		Accuracy: 0.6906214689265537
# 	Ant 4 :
# 		Path: [34, 15, 23, 53, 44, 27, 10, 48, 16, 18, 12, 51, 67, 28, 50]
# 		Accuracy: 0.683276836158192
# 	Ant 5 :
# 		Path: [14, 29, 50, 23, 52, 65, 63, 19, 38, 11, 1, 56, 59, 53, 10]
# 		Accuracy: 0.7001694915254237
# 	Ant 6 :
# 		Path: [63, 58, 2, 36, 37, 11, 13, 52, 42, 9, 45, 50, 38, 19, 59]
# 		Accuracy: 0.683502824858757
# 	Ant 7 :
# 		Path: [50, 63, 60, 28, 53, 37, 58, 57, 8, 65, 67, 21, 40, 41, 38]
# 		Accuracy: 0.7003389830508474
# 	Ant 8 :
# 		Path: [67, 11, 18, 49, 36, 2, 44, 4, 37, 26, 10, 22, 47, 29, 5]
# 		Accuracy: 0.7039548022598868
# 	Ant 9 :
# 		Path: [20, 34, 67, 12, 13, 59, 50, 19, 37, 22, 54, 38, 64, 63, 11]
# 		Accuracy: 0.7070621468926553
# 	Ant 10 :
# 		Path: [57, 67, 48, 52, 40, 60, 15, 19, 12, 16, 63, 51, 44, 50, 27]
# 		Accuracy: 0.6767796610169492
# 	Ant 11 :
# 		Path: [27, 68, 16, 2, 64, 48, 14, 29, 43, 11, 30, 45, 59, 25, 20]
# 		Accuracy: 0.710225988700565
# 	Ant 12 :
# 		Path: [59, 10, 2, 12, 9, 50, 30, 19, 25, 52, 14, 37, 60, 49, 65]
# 		Accuracy: 0.723954802259887
# 	Ant 13 :
# 		Path: [20, 16, 57, 5, 50, 43, 65, 25, 8, 22, 11, 44, 30, 51, 58]
# 		Accuracy: 0.7168926553672316
# 	Ant 14 :
# 		Path: [37, 12, 48, 16, 49, 13, 11, 67, 63, 43, 30, 18, 23, 56, 9]
# 		Accuracy: 0.6734463276836158
# 	Ant 15 :
# 		Path: [9, 59, 21, 12, 33, 29, 11, 38, 63, 8, 16, 19, 49, 30, 51]
# 		Accuracy: 0.6970056497175141
# 	Ant 16 :
# 		Path: [67, 28, 14, 51, 63, 29, 49, 19, 52, 38, 69, 57, 2, 18, 11]
# 		Accuracy: 0.7138983050847456
# 	Ant 17 :
# 		Path: [41, 57, 63, 68, 49, 37, 42, 44, 9, 18, 36, 5, 20, 58, 0]
# 		Accuracy: 0.7170621468926555
# 	Ant 18 :
# 		Path: [67, 42, 40, 18, 57, 16, 60, 9, 37, 68, 35, 50, 8, 15, 58]
# 		Accuracy: 0.6969491525423728
# 	Ant 19 :
# 		Path: [57, 11, 49, 23, 8, 29, 20, 27, 38, 42, 24, 56, 40, 9, 14]
# 		Accuracy: 0.7071186440677966
# Colony 26 :
# 	Ant 0 :
# 		Path: [67, 57, 44, 10, 9, 38, 59, 14, 24, 41, 52, 12, 37, 16, 49]
# 		Accuracy: 0.7103954802259886
# 	Ant 1 :
# 		Path: [52, 14, 33, 50, 15, 67, 37, 12, 65, 53, 38, 40, 31, 9, 63]
# 		Accuracy: 0.6833898305084746
# 	Ant 2 :
# 		Path: [52, 63, 11, 57, 9, 65, 67, 59, 29, 44, 43, 14, 51, 16, 50]
# 		Accuracy: 0.6598305084745764
# 	Ant 3 :
# 		Path: [28, 67, 34, 65, 43, 16, 12, 51, 33, 57, 29, 10, 18, 15, 20]
# 		Accuracy: 0.6769491525423728
# 	Ant 4 :
# 		Path: [60, 12, 25, 46, 11, 53, 57, 36, 38, 10, 15, 63, 0, 50, 51]
# 		Accuracy: 0.6936158192090396
# 	Ant 5 :
# 		Path: [25, 21, 33, 67, 41, 51, 49, 9, 12, 60, 0, 57, 56, 38, 5]
# 		Accuracy: 0.6665536723163842
# 	Ant 6 :
# 		Path: [22, 57, 43, 25, 59, 38, 10, 8, 49, 46, 44, 65, 47, 52, 60]
# 		Accuracy: 0.7341242937853107
# 	Ant 7 :
# 		Path: [10, 65, 31, 14, 19, 59, 50, 3, 12, 69, 38, 43, 67, 47, 5]
# 		Accuracy: 0.6968926553672317
# 	Ant 8 :
# 		Path: [58, 43, 57, 12, 67, 41, 59, 7, 22, 30, 8, 63, 14, 19, 23]
# 		Accuracy: 0.6766666666666666
# 	Ant 9 :
# 		Path: [44, 64, 10, 13, 12, 52, 67, 63, 53, 18, 28, 16, 50, 2, 9]
# 		Accuracy: 0.6802259887005649
# 	Ant 10 :
# 		Path: [21, 67, 49, 27, 68, 15, 57, 9, 52, 12, 25, 63, 44, 53, 58]
# 		Accuracy: 0.6596610169491525
# 	Ant 11 :
# 		Path: [43, 10, 18, 47, 9, 50, 56, 51, 44, 11, 8, 30, 22, 37, 12]
# 		Accuracy: 0.6903389830508474
# 	Ant 12 :
# 		Path: [33, 19, 18, 30, 12, 67, 14, 47, 15, 10, 38, 16, 41, 22, 57]
# 		Accuracy: 0.680225988700565
# 	Ant 13 :
# 		Path: [47, 59, 63, 42, 33, 57, 67, 69, 6, 13, 12, 8, 2, 10, 11]
# 		Accuracy: 0.6798305084745763
# 	Ant 14 :
# 		Path: [37, 38, 23, 16, 51, 65, 9, 59, 21, 63, 30, 25, 19, 10, 5]
# 		Accuracy: 0.7003954802259887
# 	Ant 15 :
# 		Path: [67, 24, 26, 44, 63, 59, 50, 19, 38, 43, 54, 11, 16, 48, 65]
# 		Accuracy: 0.6866666666666666
# 	Ant 16 :
# 		Path: [19, 65, 2, 67, 53, 44, 23, 43, 8, 21, 36, 9, 47, 29, 50]
# 		Accuracy: 0.7105649717514124
# 	Ant 17 :
# 		Path: [63, 15, 18, 49, 57, 60, 59, 30, 56, 19, 40, 43, 65, 51, 50]
# 		Accuracy: 0.7375141242937854
# 	Ant 18 :
# 		Path: [5, 67, 18, 1, 11, 16, 22, 30, 65, 63, 19, 57, 52, 56, 9]
# 		Accuracy: 0.659774011299435
# 	Ant 19 :
# 		Path: [57, 11, 18, 51, 37, 67, 28, 63, 9, 16, 38, 49, 42, 22, 50]
# 		Accuracy: 0.7106779661016949
# Colony 27 :
# 	Ant 0 :
# 		Path: [33, 51, 44, 56, 38, 63, 43, 49, 30, 24, 47, 40, 15, 67, 50]
# 		Accuracy: 0.690225988700565
# 	Ant 1 :
# 		Path: [0, 8, 57, 37, 23, 27, 10, 19, 54, 69, 42, 51, 67, 14, 13]
# 		Accuracy: 0.6631638418079097
# 	Ant 2 :
# 		Path: [2, 44, 59, 18, 63, 14, 41, 49, 15, 42, 34, 65, 60, 67, 40]
# 		Accuracy: 0.7105649717514123
# 	Ant 3 :
# 		Path: [58, 57, 63, 67, 65, 10, 8, 30, 9, 44, 34, 19, 38, 2, 16]
# 		Accuracy: 0.6736158192090395
# 	Ant 4 :
# 		Path: [14, 27, 20, 10, 63, 52, 11, 50, 36, 38, 65, 28, 57, 16, 43]
# 		Accuracy: 0.6866666666666666
# 	Ant 5 :
# 		Path: [30, 36, 46, 18, 38, 52, 50, 31, 2, 11, 56, 16, 10, 12, 44]
# 		Accuracy: 0.7038983050847458
# 	Ant 6 :
# 		Path: [52, 38, 15, 6, 67, 10, 22, 9, 63, 21, 53, 65, 18, 60, 59]
# 		Accuracy: 0.6870056497175141
# 	Ant 7 :
# 		Path: [44, 53, 59, 63, 10, 38, 50, 29, 37, 51, 9, 52, 57, 30, 42]
# 		Accuracy: 0.6900564971751412
# 	Ant 8 :
# 		Path: [65, 48, 16, 49, 57, 59, 58, 38, 27, 14, 56, 43, 7, 50, 41]
# 		Accuracy: 0.7204519774011299
# 	Ant 9 :
# 		Path: [2, 65, 42, 52, 36, 50, 10, 33, 40, 38, 21, 9, 7, 19, 14]
# 		Accuracy: 0.6668926553672316
# 	Ant 10 :
# 		Path: [45, 67, 6, 56, 36, 59, 23, 38, 65, 8, 20, 16, 40, 48, 4]
# 		Accuracy: 0.6968926553672316
# 	Ant 11 :
# 		Path: [12, 57, 23, 15, 14, 67, 60, 38, 11, 21, 44, 16, 6, 8, 13]
# 		Accuracy: 0.6633898305084747
# 	Ant 12 :
# 		Path: [19, 56, 0, 67, 36, 59, 63, 44, 50, 27, 25, 12, 47, 52, 16]
# 		Accuracy: 0.659774011299435
# 	Ant 13 :
# 		Path: [25, 14, 38, 57, 59, 67, 42, 52, 44, 63, 22, 51, 29, 12, 11]
# 		Accuracy: 0.6533333333333333
# 	Ant 14 :
# 		Path: [43, 57, 49, 52, 10, 67, 65, 50, 6, 38, 18, 56, 42, 12, 25]
# 		Accuracy: 0.7038418079096045
# 	Ant 15 :
# 		Path: [48, 38, 15, 49, 23, 9, 67, 68, 57, 14, 51, 16, 18, 63, 21]
# 		Accuracy: 0.7003389830508475
# 	Ant 16 :
# 		Path: [10, 11, 30, 63, 57, 44, 9, 49, 28, 18, 25, 27, 51, 59, 67]
# 		Accuracy: 0.7207344632768361
# 	Ant 17 :
# 		Path: [24, 59, 11, 65, 25, 48, 63, 5, 8, 0, 9, 57, 56, 38, 31]
# 		Accuracy: 0.6735028248587571
# 	Ant 18 :
# 		Path: [48, 44, 30, 57, 41, 40, 60, 12, 53, 8, 58, 38, 67, 27, 63]
# 		Accuracy: 0.6629378531073447
# 	Ant 19 :
# 		Path: [10, 21, 50, 38, 2, 30, 63, 25, 46, 28, 51, 9, 49, 14, 37]
# 		Accuracy: 0.6970621468926554
# Colony 28 :
# 	Ant 0 :
# 		Path: [10, 9, 6, 67, 38, 57, 53, 33, 63, 52, 34, 11, 44, 8, 23]
# 		Accuracy: 0.6802824858757063
# 	Ant 1 :
# 		Path: [29, 63, 19, 56, 57, 48, 52, 50, 38, 30, 15, 46, 12, 37, 20]
# 		Accuracy: 0.7306214689265537
# 	Ant 2 :
# 		Path: [15, 18, 63, 38, 59, 33, 44, 3, 47, 20, 42, 50, 14, 9, 16]
# 		Accuracy: 0.6801129943502825
# 	Ant 3 :
# 		Path: [44, 63, 15, 19, 65, 41, 43, 54, 42, 11, 57, 37, 10, 18, 9]
# 		Accuracy: 0.6700564971751413
# 	Ant 4 :
# 		Path: [43, 56, 19, 10, 16, 48, 51, 12, 15, 9, 30, 14, 28, 65, 53]
# 		Accuracy: 0.6463276836158192
# 	Ant 5 :
# 		Path: [57, 46, 9, 11, 59, 51, 52, 43, 33, 36, 42, 18, 38, 14, 53]
# 		Accuracy: 0.6836723163841808
# 	Ant 6 :
# 		Path: [60, 27, 35, 67, 50, 56, 38, 59, 8, 18, 51, 12, 65, 22, 6]
# 		Accuracy: 0.70045197740113
# 	Ant 7 :
# 		Path: [43, 28, 34, 38, 44, 6, 9, 4, 53, 19, 25, 10, 12, 67, 63]
# 		Accuracy: 0.690225988700565
# 	Ant 8 :
# 		Path: [53, 32, 45, 24, 11, 64, 9, 60, 63, 19, 0, 2, 58, 22, 51]
# 		Accuracy: 0.703728813559322
# 	Ant 9 :
# 		Path: [43, 38, 50, 34, 8, 67, 36, 51, 14, 12, 56, 27, 22, 10, 63]
# 		Accuracy: 0.6900564971751411
# 	Ant 10 :
# 		Path: [67, 56, 16, 63, 59, 25, 9, 29, 12, 45, 58, 49, 11, 6, 37]
# 		Accuracy: 0.7238983050847457
# 	Ant 11 :
# 		Path: [48, 59, 34, 5, 27, 67, 51, 52, 49, 63, 6, 10, 9, 68, 30]
# 		Accuracy: 0.7173446327683616
# 	Ant 12 :
# 		Path: [57, 12, 47, 15, 58, 28, 45, 53, 30, 63, 44, 43, 1, 16, 11]
# 		Accuracy: 0.6935593220338983
# 	Ant 13 :
# 		Path: [43, 11, 23, 59, 51, 67, 47, 38, 63, 37, 19, 33, 41, 22, 52]
# 		Accuracy: 0.7272881355932204
# 	Ant 14 :
# 		Path: [42, 36, 22, 59, 51, 12, 20, 65, 49, 58, 9, 11, 43, 60, 50]
# 		Accuracy: 0.7205084745762711
# 	Ant 15 :
# 		Path: [12, 53, 6, 68, 15, 2, 44, 40, 59, 19, 47, 42, 8, 50, 28]
# 		Accuracy: 0.6766666666666666
# 	Ant 16 :
# 		Path: [43, 12, 63, 5, 65, 59, 22, 42, 44, 18, 8, 9, 20, 56, 38]
# 		Accuracy: 0.7102824858757062
# 	Ant 17 :
# 		Path: [11, 18, 42, 50, 51, 40, 54, 37, 6, 38, 58, 43, 48, 44, 31]
# 		Accuracy: 0.6867796610169491
# 	Ant 18 :
# 		Path: [57, 49, 10, 0, 44, 12, 2, 38, 11, 19, 37, 41, 65, 50, 25]
# 		Accuracy: 0.727457627118644
# 	Ant 19 :
# 		Path: [18, 48, 41, 52, 53, 40, 29, 21, 38, 67, 49, 59, 23, 56, 30]
# 		Accuracy: 0.6937853107344634
# Colony 29 :
# 	Ant 0 :
# 		Path: [47, 9, 49, 58, 64, 10, 37, 38, 15, 44, 48, 16, 2, 68, 67]
# 		Accuracy: 0.6632203389830509
# 	Ant 1 :
# 		Path: [9, 2, 49, 56, 38, 16, 18, 44, 30, 12, 42, 37, 36, 51, 15]
# 		Accuracy: 0.6770056497175141
# 	Ant 2 :
# 		Path: [2, 36, 56, 12, 18, 21, 64, 27, 37, 67, 5, 22, 33, 49, 11]
# 		Accuracy: 0.6835028248587571
# 	Ant 3 :
# 		Path: [2, 6, 44, 30, 0, 10, 43, 33, 11, 18, 52, 65, 56, 27, 42]
# 		Accuracy: 0.6799999999999999
# 	Ant 4 :
# 		Path: [6, 10, 51, 14, 49, 43, 25, 9, 52, 59, 8, 20, 58, 38, 12]
# 		Accuracy: 0.7071751412429379
# 	Ant 5 :
# 		Path: [50, 53, 10, 30, 16, 9, 6, 8, 11, 43, 57, 38, 46, 51, 58]
# 		Accuracy: 0.7203954802259886
# 	Ant 6 :
# 		Path: [31, 10, 22, 33, 58, 49, 8, 65, 63, 9, 18, 19, 14, 42, 23]
# 		Accuracy: 0.6835593220338982
# 	Ant 7 :
# 		Path: [43, 11, 14, 8, 58, 45, 49, 63, 22, 68, 12, 28, 10, 42, 67]
# 		Accuracy: 0.7003954802259886
# 	Ant 8 :
# 		Path: [9, 14, 51, 54, 30, 38, 28, 56, 12, 32, 67, 63, 40, 10, 48]
# 		Accuracy: 0.6769491525423729
# 	Ant 9 :
# 		Path: [9, 59, 36, 43, 22, 19, 38, 15, 54, 63, 30, 10, 8, 18, 46]
# 		Accuracy: 0.727457627118644
# 	Ant 10 :
# 		Path: [37, 59, 52, 29, 44, 38, 14, 16, 67, 49, 10, 22, 12, 0, 50]
# 		Accuracy: 0.7205084745762712
# 	Ant 11 :
# 		Path: [34, 59, 0, 38, 24, 12, 7, 30, 63, 60, 48, 36, 68, 25, 50]
# 		Accuracy: 0.70045197740113
# 	Ant 12 :
# 		Path: [14, 67, 18, 53, 30, 59, 44, 50, 21, 57, 65, 9, 15, 63, 56]
# 		Accuracy: 0.686723163841808
# 	Ant 13 :
# 		Path: [16, 22, 14, 44, 59, 2, 63, 65, 53, 67, 38, 11, 19, 69, 57]
# 		Accuracy: 0.6801129943502825
# 	Ant 14 :
# 		Path: [25, 57, 2, 44, 11, 50, 38, 63, 18, 23, 52, 47, 42, 69, 37]
# 		Accuracy: 0.7206779661016949
# 	Ant 15 :
# 		Path: [9, 63, 42, 57, 0, 65, 50, 27, 44, 14, 59, 23, 67, 29, 38]
# 		Accuracy: 0.7036158192090396
# 	Ant 16 :
# 		Path: [64, 67, 33, 2, 48, 44, 31, 49, 8, 9, 19, 41, 63, 65, 37]
# 		Accuracy: 0.6800564971751413
# 	Ant 17 :
# 		Path: [18, 27, 63, 54, 38, 48, 2, 69, 49, 41, 47, 57, 60, 15, 50]
# 		Accuracy: 0.7272881355932203
# 	Ant 18 :
# 		Path: [11, 14, 58, 42, 59, 50, 38, 67, 65, 48, 19, 53, 37, 68, 9]
# 		Accuracy: 0.7236158192090395
# 	Ant 19 :
# 		Path: [25, 67, 18, 57, 68, 0, 11, 63, 56, 14, 23, 49, 51, 38, 2]
# 		Accuracy: 0.7103954802259886

# %%
fs.printTestingResults()
# Out:
# The final subset of features is:  [9, 59, 36, 43, 22, 19, 38, 15, 54, 63, 30, 10, 8, 18, 46]
# Top 5 ants:
# Path:  [6, 10, 51, 14, 49, 43, 25, 9, 52, 59, 8, 20, 58, 38, 12] 	 | IPC:  0.025846447615548006
# Path:  [37, 59, 52, 29, 44, 38, 14, 16, 67, 49, 10, 22, 12, 0, 50] 	 | IPC:  0.02561817642159955
# Path:  [11, 14, 58, 42, 59, 50, 38, 67, 65, 48, 19, 53, 37, 68, 9] 	 | IPC:  0.02455564414019645
# Path:  [9, 59, 36, 43, 22, 19, 38, 15, 54, 63, 30, 10, 8, 18, 46] 	 | IPC:  0.02413783455958069
# Path:  [50, 53, 10, 30, 16, 9, 6, 8, 11, 43, 57, 38, 46, 51, 58] 	 | IPC:  0.022733075066321374
# Number of features:  15
# Subset of features dataset accuracy:
# 	 CV-Training set:  0.727457627118644
# 	 Testing set    :  0.696969696969697
# 	 Time elapsed reading data        :  0.032608985900878906
# 	 Time elapsed in LUT compute      :  1.224297285079956
# 	 Time elapsed reseting values     :  15.716305017471313
# 	 Time elapsed in local search     :  20.32356095314026
# 	 Time elapsed updating pheromones :  0.0059888362884521484
#
# TOTAL AUC FROM MODEL:  0.7943944353518821
# AUC Score ([6, 10, 51, 14, 49, 43, 25, 9, 52, 59, 8, 20, 58, 38, 12], 0.025846447615548006): 0.6849427168576104
# AUC Score ([37, 59, 52, 29, 44, 38, 14, 16, 67, 49, 10, 22, 12, 0, 50], 0.02561817642159955): 0.4596972176759411
# AUC Score ([11, 14, 58, 42, 59, 50, 38, 67, 65, 48, 19, 53, 37, 68, 9], 0.02455564414019645): 0.6159983633387889
# AUC Score ([9, 59, 36, 43, 22, 19, 38, 15, 54, 63, 30, 10, 8, 18, 46], 0.02413783455958069): 0.7943944353518821
# AUC Score ([50, 53, 10, 30, 16, 9, 6, 8, 11, 43, 57, 38, 46, 51, 58], 0.022733075066321374): 0.5243453355155483

# %%
selected_features = fs.selectedPaths()
selected_features = selected_features[0]
selected_features
# Out:
# [[9, 59, 36, 43, 22, 19, 38, 15, 54, 63, 30, 10, 8, 18, 46], [18, 27, 63, 54, 38, 48, 2, 69, 49, 41, 47, 57, 60, 15, 50], [11, 14, 58, 42, 59, 50, 38, 67, 65, 48, 19, 53, 37, 68, 9], [25, 57, 2, 44, 11, 50, 38, 63, 18, 23, 52, 47, 42, 69, 37], [37, 59, 52, 29, 44, 38, 14, 16, 67, 49, 10, 22, 12, 0, 50], [50, 53, 10, 30, 16, 9, 6, 8, 11, 43, 57, 38, 46, 51, 58], [25, 67, 18, 57, 68, 0, 11, 63, 56, 14, 23, 49, 51, 38, 2], [6, 10, 51, 14, 49, 43, 25, 9, 52, 59, 8, 20, 58, 38, 12], [9, 63, 42, 57, 0, 65, 50, 27, 44, 14, 59, 23, 67, 29, 38], [34, 59, 0, 38, 24, 12, 7, 30, 63, 60, 48, 36, 68, 25, 50], [43, 11, 14, 8, 58, 45, 49, 63, 22, 68, 12, 28, 10, 42, 67], [14, 67, 18, 53, 30, 59, 44, 50, 21, 57, 65, 9, 15, 63, 56], [31, 10, 22, 33, 58, 49, 8, 65, 63, 9, 18, 19, 14, 42, 23], [2, 36, 56, 12, 18, 21, 64, 27, 37, 67, 5, 22, 33, 49, 11], [16, 22, 14, 44, 59, 2, 63, 65, 53, 67, 38, 11, 19, 69, 57], [64, 67, 33, 2, 48, 44, 31, 49, 8, 9, 19, 41, 63, 65, 37], [2, 6, 44, 30, 0, 10, 43, 33, 11, 18, 52, 65, 56, 27, 42], [9, 2, 49, 56, 38, 16, 18, 44, 30, 12, 42, 37, 36, 51, 15], [9, 14, 51, 54, 30, 38, 28, 56, 12, 32, 67, 63, 40, 10, 48], [47, 9, 49, 58, 64, 10, 37, 38, 15, 44, 48, 16, 2, 68, 67]]
# [9, 59, 36, 43, 22, 19, 38, 15, 54, 63, 30, 10, 8, 18, 46]

# %%
#from classifier import Classifier

# %%
# classifier = Classifier(selected_features, './rtfDataSet.csv')
# classifier.run()

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import accuracy_score, precision_score, recall_score, roc_auc_score, f1_score, matthews_corrcoef, roc_curve, auc, precision_recall_curve
from statistics import mean, stdev
from sklearn.metrics import confusion_matrix


df = pd.read_csv('./rtfDataSet.csv')

x = df.iloc[:, selected_features]

# Input_ y_Target_Variable.
y = df.iloc[:, -1]

# Normalize
scaler = MinMaxScaler()
x_scaled = scaler.fit_transform(x)

criterions = ['entropy','gini']

for criterion in criterions:
    skf = StratifiedKFold(n_splits=10, shuffle=True, random_state=42)
    accu_list = []
    precision_list = []
    recall_list = []
    auc_list = []
    f1_list = []
    mcc_list = []
    sensitivity_list = []
    specificity_list = []

    for train_index, test_index in skf.split(x_scaled, y):
        x_train_fold, x_test_fold = x_scaled[train_index], x_scaled[test_index]
        y_train_fold, y_test_fold = y.iloc[train_index], y.iloc[test_index]

        # Inicializar y entrenar el modelo del árbol de decisión
        model = DecisionTreeClassifier(criterion=criterion)
        model.fit(x_train_fold, y_train_fold)

        # Predecir las etiquetas para el conjunto de prueba
        y_pred = model.predict(x_test_fold)

        # Calcular métricas y agregar a las listas
        accu_list.append(accuracy_score(y_test_fold, y_pred))
        precision_list.append(precision_score(y_test_fold, y_pred))
        recall_list.append(recall_score(y_test_fold, y_pred))
        auc_list.append(roc_auc_score(y_test_fold, y_pred))
        f1_list.append(f1_score(y_test_fold, y_pred))
        mcc_list.append(matthews_corrcoef(y_test_fold, y_pred))

        # Calcular sensibilidad y especificidad
        tn, fp, fn, tp = confusion_matrix(y_test_fold, y_pred).ravel()
        sensitivity_list.append(tp / (tp + fn))
        specificity_list.append(tn / (tn + fp))
        

    # Print results
    print(f"Criterio: {criterion}")
    print('Metrics Results:')
    print('-'*30)
    print(f"Accuracy: {mean(accu_list)*100:.2f}% ± {stdev(accu_list):.2f}")
    print(f"Precision: {mean(precision_list)*100:.2f}% ± {stdev(precision_list):.2f}")
    print(f"Recall: {mean(recall_list)*100:.2f}% ± {stdev(recall_list):.2f}")
    print(f"AUC: {mean(auc_list)*100:.2f}% ± {stdev(auc_list):.2f}")
    print(f"F1 Score: {mean(f1_list)*100:.2f}% ± {stdev(f1_list):.2f}")
    print(f"MCC: {mean(mcc_list)*100:.2f}% ± {stdev(mcc_list):.2f}")
    print(f"Sensitivity: {mean(sensitivity_list)*100:.2f}% ± {stdev(sensitivity_list):.2f}")
    print(f"Specificity: {mean(specificity_list)*100:.2f}% ± {stdev(specificity_list):.2f}\n")


    # Plot Confusion Matrix 
    matrix = confusion_matrix(y_test_fold, y_pred)
    plt.figure(figsize=(10,7))
    sns.set(font_scale=1.4)  # for label size
    sns.heatmap(matrix, annot=True, annot_kws={"size": 16}, fmt='g')
    plt.xlabel('True')
    plt.ylabel('Predicted')
    plt.title(f'Confusion Matrix - Criterion: {criterion}')
    plt.show()

    #Plot ROC Curve
    fpr, tpr, _ = roc_curve(y_test_fold, y_pred)
    roc_auc = auc(fpr, tpr)
    plt.figure()
    lw = 2
    plt.plot(fpr, tpr, color='darkorange', lw=lw, label='ROC curve (area = %0.2f)' % roc_auc)
    plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title(f'ROC - Criterion: {criterion}')
    plt.legend(loc="lower right")
    plt.show()
    
    # Plot Precision vs Recall
    precision, recall, thresholds = precision_recall_curve(y_test_fold, y_pred)
    plt.figure()
    plt.plot(recall, precision, color='blue', lw=lw)
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('Recall')
    plt.ylabel('Precision')
    plt.title(f'Precision vs Recall - Criterion: {criterion}')
    plt.show()
# Out:
# Criterio: entropy
# Metrics Results:
# ------------------------------
# Accuracy: 68.17% ± 0.05
# Precision: 69.36% ± 0.04
# Recall: 68.48% ± 0.16
# AUC: 68.29% ± 0.05
# F1 Score: 67.91% ± 0.08
# MCC: 37.58% ± 0.11
# Sensitivity: 68.48% ± 0.16
# Specificity: 68.11% ± 0.09
# Criterio: gini
# Metrics Results:
# ------------------------------
# Accuracy: 71.94% ± 0.06
# Precision: 71.51% ± 0.05
# Recall: 75.19% ± 0.11
# AUC: 71.83% ± 0.06
# F1 Score: 72.93% ± 0.07
# MCC: 44.39% ± 0.13
# Sensitivity: 75.19% ± 0.11
# Specificity: 68.47% ± 0.08

# %%
from C45 import C45Classifier

skf = StratifiedKFold(n_splits=10, shuffle=True, random_state=42)
accu_list = []
precision_list = []
recall_list = []
auc_list = []
f1_list = []
mcc_list = []
sensitivity_list = []
specificity_list = []

for train_index, test_index in skf.split(x_scaled, y):
    x_train_fold, x_test_fold = x_scaled[train_index], x_scaled[test_index]
    y_train_fold, y_test_fold = y.iloc[train_index], y.iloc[test_index]

    # Inicializar y entrenar el modelo del árbol de decisión
    features = [''.join(i for i in str(x) if i.isalnum()).replace(' ', '_') for x in selected_features]
    model = C45Classifier()
    model.fit(x_train_fold, y_train_fold)
    
    # Predecir las etiquetas para el conjunto de prueba
    y_pred = model.predict(x_test_fold)

    # Calcular métricas y agregar a las listas
    accu_list.append(accuracy_score(y_test_fold, y_pred))
    precision_list.append(precision_score(y_test_fold, y_pred))
    recall_list.append(recall_score(y_test_fold, y_pred))
    auc_list.append(roc_auc_score(y_test_fold, y_pred))
    f1_list.append(f1_score(y_test_fold, y_pred))
    mcc_list.append(matthews_corrcoef(y_test_fold, y_pred))

    # Calcular sensibilidad y especificidad
    tn, fp, fn, tp = confusion_matrix(y_test_fold, y_pred).ravel()
    sensitivity_list.append(tp / (tp + fn))
    specificity_list.append(tn / (tn + fp))
    
# Print results
print(f"Criterio: Gain Ratio")
print('Metrics Results:')
print('-'*30)
print(f"Accuracy: {mean(accu_list)*100:.2f}% ± {stdev(accu_list):.2f}")
print(f"Precision: {mean(precision_list)*100:.2f}% ± {stdev(precision_list):.2f}")
print(f"Recall: {mean(recall_list)*100:.2f}% ± {stdev(recall_list):.2f}")
print(f"AUC: {mean(auc_list)*100:.2f}% ± {stdev(auc_list):.2f}")
print(f"F1 Score: {mean(f1_list)*100:.2f}% ± {stdev(f1_list):.2f}")
print(f"MCC: {mean(mcc_list)*100:.2f}% ± {stdev(mcc_list):.2f}")
print(f"Sensitivity: {mean(sensitivity_list)*100:.2f}% ± {stdev(sensitivity_list):.2f}")
print(f"Specificity: {mean(specificity_list)*100:.2f}% ± {stdev(specificity_list):.2f}\n")


# Plot Confusion Matrix 
matrix = confusion_matrix(y_test_fold, y_pred)
plt.figure(figsize=(10,7))
sns.set(font_scale=1.4)  # for label size
sns.heatmap(matrix, annot=True, annot_kws={"size": 16}, fmt='g')
plt.xlabel('True')
plt.ylabel('Predicted')
plt.title(f'Confusion Matrix - Criterion: Gain Ratio')
plt.show()

#Plot ROC Curve
fpr, tpr, _ = roc_curve(y_test_fold, y_pred)
roc_auc = auc(fpr, tpr)
plt.figure()
lw = 2
plt.plot(fpr, tpr, color='darkorange', lw=lw, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title(f'ROC - Criterion: Gain Ratio')
plt.legend(loc="lower right")
plt.show()

# Plot Precision vs Recall
precision, recall, thresholds = precision_recall_curve(y_test_fold, y_pred)
plt.figure()
plt.plot(recall, precision, color='blue', lw=lw)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title(f'Precision vs Recall - Criterion: Gain Ratio')
plt.show()
# Out:
# Criterio: Gain Ratio
# Metrics Results:
# ------------------------------
# Accuracy: 57.33% ± 0.04
# Precision: 54.80% ± 0.03
# Recall: 94.02% ± 0.05
# AUC: 56.56% ± 0.04
# F1 Score: 69.21% ± 0.03
# MCC: 20.00% ± 0.12
# Sensitivity: 94.02% ± 0.05
# Specificity: 19.11% ± 0.07
